# %% [markdown]
# # Dialogue Summarization EDA
#
# 이 노트북은 대회용 `train/dev/test` 대화 요약 데이터를 탐색하고,
# 모델링/전처리/프롬프트 설계를 위한 인사이트를 얻기 위한 EDA 계획 및 실행을 담습니다.

# %% [markdown]
# ## 1. EDA 전체 계획
#
# 1. **데이터 구조 파악**
#    - `train/dev/test` 행 개수, 컬럼(`fname, dialogue, summary, topic`) 구조 확인
#    - topic 분포 (train/dev) 비교, test에 topic 유무 확인
#
# 2. **대화/요약 길이 통계**
#    - 문자/토큰 기준 길이 분포 (평균, 중앙값, 상/하위 quantile)
#    - encoder_max_len=1024, decoder_max_len=80 기준으로 잘리는 비율 추정
#    - 발화(turn) 개수 분포 (#Person1/#Person2 등장 회수)
#
# 3. **토픽/스타일 분석**
#    - topic별 평균 대화 길이 / 요약 길이 비교
#    - 대표적인 대화-요약 페어 몇 개 샘플링해서, 요약 스타일(존댓말/반말, 요약의 추상화/추출 비율) 파악
#    - 요약에서 자주 등장하는 키워드/표현 조사 (간단한 빈도/WordCloud 수준)
#
# 4. **train/dev 데이터 분포 차이 체크**
#    - 길이 분포, topic 분포, 자주 등장하는 단어 등 비교
#    - 분포가 비슷한지, dev가 특정 topic에 편향되어 있는지 확인
#
# 5. **모델/프롬프트 설계에 직접 연결되는 분석**
#    - 긴 대화에서 앞/뒤 어느 부분이 요약에 더 많이 반영되는지 (간단한 n-gram overlap 위치 분석)
#    - 스타일 프롬프트 후보 문구를 몇 개 정의하고, 요약 스타일과 매칭되는지 눈으로 검증
#    - KoBART/T5 토크나이저 기준 토큰 길이 분포 (추후 필요 시)
#
# 6. **제출 파일/파이프라인 sanity check**
#    - `prediction/*.csv`에서 `fname` 정렬/중복 여부, summary 공백/길이 확인
#    - 극단적으로 짧거나 긴 요약 몇 개 샘플링하여 품질/스타일 확인

# %%
# 데이터 로딩 셀입니다.
# - notebooks/ 폴더에서 실행해도 항상 프로젝트 루트의 data/를 바라보도록 경로를 처리합니다.
import pandas as pd
from pathlib import Path

# 이 노트북이 있는 위치 기준으로 프로젝트 루트 추정
NOTEBOOK_DIR = Path().resolve()
ROOT_DIR = NOTEBOOK_DIR.parent  # nlp_contest/
DATA_DIR = ROOT_DIR / "data"

TRAIN_PATH = DATA_DIR / "train.csv"
DEV_PATH = DATA_DIR / "dev.csv"
TEST_PATH = DATA_DIR / "test.csv"

missing = [p for p in [TRAIN_PATH, DEV_PATH, TEST_PATH] if not p.exists()]
if missing:
    missing_str = ", ".join(str(p) for p in missing)
    raise FileNotFoundError(
        f"다음 파일을 찾을 수 없습니다: {missing_str}\n"
        "- 프로젝트 루트(nlp_contest) 아래 data/에 csv를 넣은 뒤 이 셀을 다시 실행하세요."
    )

train_df = pd.read_csv(TRAIN_PATH)
dev_df = pd.read_csv(DEV_PATH)
test_df = pd.read_csv(TEST_PATH)

train_df.head(), dev_df.head(), test_df.head()
# Out:
# (     fname                                           dialogue  \
#  0  train_0  #Person1#: 안녕하세요, Mr. Smith. 저는 Dr. Hawkins입니다...
#  1  train_1  #Person1#: 안녕하세요, Mrs. Parker. 잘 지내셨나요?\n#Pers...
#  2  train_2  #Person1#: 저기요, 열쇠 세트 본 적 있어요?\n#Person2#: 어떤 ...
#  3  train_3  #Person1#: 너 여자친구 있는 거 왜 말 안 했어?\n#Person2#: 미...
#  4  train_4  #Person1#: 안녕, 오늘 너무 멋져 보이네요. 저랑 춤 한 곡 추실래요?\n...
#
#                                               summary      topic
#  0  Mr. Smith는 Dr. Hawkins에게 건강검진을 받으러 와서, 매년 검진 필...       건강검진
#  1  Mrs. Parker가 Ricky와 함께 백신 접종을 위해 방문하였고, Dr. Pe...      백신 접종
#  2  #Person1#은 열쇠 세트를 잃어버리고 #Person2#에게 찾는 것을 도와달라...      열쇠 분실
#  3  #Person1#은 #Person2#가 여자친구가 있고 결혼할 예정이라는 사실을 말...  여자친구와의 결혼
#  4  Malik은 Wen과 Nikki에게 춤을 제안하고, Wen은 발을 밟는 것을 감수하...       춤 제안  ,
#     fname                                           dialogue  \
#  0  dev_0  #Person1#: 안녕하세요, 오늘 기분이 어떠세요?\n#Person2#: 요즘 ...
#  1  dev_1  #Person1#: 야 Jimmy, 오늘 좀 이따 운동하러 가자.\n#Person2...
#  2  dev_2  #Person1#: 나 진짜 건강에 안 좋은 음식 좀 그만 먹어야겠어. \n#Per...
#  3  dev_3  #Person1#: 너 UFO 믿어?\n#Person2#: 당연하지, 있는 거 아냐...
#  4  dev_4  #Person1#: 오늘 학교 갔어?\n#Person2#: 당연히 갔지. 너는?\n...
#
#                                               summary      topic
#  0  #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하...      의사 상담
#  1   #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.      운동 계획
#  2  #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#...     건강한 식단
#  3  #Person2#는 UFO를 믿고 꿈에서 볼 수 있다고 한다. #Person1#은 ...   UFO와 외계인
#  4  #Person1#은 오늘 학교에 가지 않았고, #Person2#는 내일 학교 대신 ...  학교와 주말 계획  ,
#      fname                                           dialogue
#  0  test_0  #Person1#: Ms. Dawson, 받아쓰기 좀 부탁드려야겠어요. \n#Per...
#  1  test_1  #Person1#: 드디어 왔네! 뭐가 이렇게 오래 걸렸어?\n#Person2#: ...
#  2  test_2  #Person1#: Kate, 여기서 일어난 일을 믿기 힘들 거야.\n#Person...
#  3  test_3  #Person1#: 생일 축하해, 이거 너를 위한 선물이야, Brian.\n#Per...
#  4  test_4  #Person1#: 이 올림픽 공원 정말 크다! \n#Person2#: 맞아. 지금...)

# %%
# 하나의 엑셀 파일에 서로 다른 시트로 저장
with pd.ExcelWriter("../analysis/all_dialogues.xlsx") as writer:
    train_df.to_excel(writer, sheet_name="train", index=False)
    dev_df.to_excel(writer,   sheet_name="dev",   index=False)
    test_df.to_excel(writer,  sheet_name="test",  index=False)

# %% [markdown]
# ## 2. 데이터 구조 및 기본 통계
#
# - 각 split의 행 개수, 컬럼, 결측치, topic 유무 등 기본 정보 확인

# %%
print("Train shape:", train_df.shape)
print("Dev shape:", dev_df.shape)
print("Test shape:", test_df.shape)

print("\nTrain columns:", train_df.columns.tolist())
print("Dev columns:", dev_df.columns.tolist())
print("Test columns:", test_df.columns.tolist())

print("\nTrain topic value_counts:\n", train_df.get("topic", pd.Series()).value_counts().head())
print("\nDev topic value_counts:\n", dev_df.get("topic", pd.Series()).value_counts().head())
# Out:
# Train shape: (12457, 4)
# Dev shape: (499, 4)
# Test shape: (499, 2)
#
# Train columns: ['fname', 'dialogue', 'summary', 'topic']
# Dev columns: ['fname', 'dialogue', 'summary', 'topic']
# Test columns: ['fname', 'dialogue']
#
# Train topic value_counts:
#  topic
# 음식 주문     130
# 취업 면접     109
# 길 안내       66
# 호텔 체크인     40
# 아파트 임대     30
# Name: count, dtype: int64
#
# Dev topic value_counts:
#  topic
# 호텔 방 예약    5
# 길 안내       4
# 취업 면접      4
# 음식 주문      4
# 신발 구매      2
# Name: count, dtype: int64

# %% [markdown]
# ## 3. 길이 분포 분석 (문자 기준)
#
# - dialogue 길이, summary 길이의 기본 통계를 보고, encoder/decoder max length 설정이 적절한지 감각을 잡습니다.

# %%
for split_name, df in [("train", train_df), ("dev", dev_df)]:
    df["dialogue_len_char"] = df["dialogue"].astype(str).str.len()
    df["summary_len_char"] = df.get("summary", "").astype(str).str.len()

    print(f"==== {split_name.upper()} ====")
    print("dialogue_len_char describe:\n", df["dialogue_len_char"].describe())
    print("summary_len_char describe:\n", df["summary_len_char"].describe())
    print()
# Out:
# ==== TRAIN ====
# dialogue_len_char describe:
#  count    12457.000000
# mean       406.083487
# std        197.566083
# min         84.000000
# 25%        280.000000
# 50%        369.000000
# 75%        500.000000
# max       2165.000000
# Name: dialogue_len_char, dtype: float64
# summary_len_char describe:
#  count    12457.000000
# mean        85.789436
# std         33.811948
# min         13.000000
# 25%         61.000000
# 50%         80.000000
# 75%        104.000000
# max        376.000000
# Name: summary_len_char, dtype: float64
#
# ==== DEV ====
# dialogue_len_char describe:
#  count     499.000000
# mean      400.054108
# std       186.163807
# min       114.000000
# 25%       273.000000
# 50%       367.000000
# 75%       487.000000
# max      1269.000000
# Name: dialogue_len_char, dtype: float64
# summary_len_char describe:
#  count    499.000000
# mean      81.206413
# std       32.577548
# min       29.000000
# 25%       58.000000
# 50%       74.000000
# 75%       96.000000
# max      283.000000
# Name: summary_len_char, dtype: float64

# %% [markdown]
# ## 4. 발화(turn) 수 분포
#
# - `#Person1#`, `#Person2#` 패턴을 이용해 대화 turn 수 분포를 대략적으로 확인합니다.

# %%
import re

def count_turns(text: str) -> int:
    return len(re.findall(r"#Person[0-9]+#", str(text)))

train_df["num_turns"] = train_df["dialogue"].apply(count_turns)
dev_df["num_turns"] = dev_df["dialogue"].apply(count_turns)

print("Train num_turns describe:\n", train_df["num_turns"].describe())
print("Dev num_turns describe:\n", dev_df["num_turns"].describe())
# Out:
# Train num_turns describe:
#  count    12457.000000
# mean         9.491451
# std          4.146670
# min          2.000000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max         59.000000
# Name: num_turns, dtype: float64
# Dev num_turns describe:
#  count    499.000000
# mean       9.398798
# std        4.010438
# min        2.000000
# 25%        6.000000
# 50%        9.000000
# 75%       12.000000
# max       29.000000
# Name: num_turns, dtype: float64

# %% [markdown]
# ## 5. topic별 길이/스타일 차이 (추후 확장)
#
# - topic이 존재한다면, topic별로 길이/turn 수/요약 길이 차이를 비교합니다.
# - 필요 시 시각화(히스토그램, 박스플롯)를 추가할 수 있습니다.

# %%
# topic별로 대화 길이 / 요약 길이 / 턴 수 통계를 보는 셀입니다.
# pandas 최신 버전에서는 여러 컬럼을 선택할 때 리스트로 넘겨야 하므로,
# ["col1", "col2", ...] 형태로 명시적으로 지정합니다.
if "topic" in train_df.columns:
    cols = ["dialogue_len_char", "summary_len_char", "num_turns"]
    topic_stats = train_df.groupby("topic")[cols].describe()
    topic_stats.head()

# %% [markdown]
# ## 6. 샘플 대화-요약 페어 확인
#
# - 무작위로 몇 개를 뽑아서, 요약 스타일과 프롬프트 설계 방향을 눈으로 확인합니다.

# %%
SAMPLE_N = 300
sample_rows = train_df.sample(SAMPLE_N, random_state=42)
for i, row in sample_rows.iterrows():
    print("==== SAMPLE ====\n")
    print("fname:", row.get("fname"))
    print("topic:", row.get("topic"))
    print("[DIALOGUE]\n", row["dialogue"][:1000])
    print("\n[SUMMARY]\n", row["summary"])
    print("\n\n")
# Out:
# ==== SAMPLE ====
#
# fname: train_396
# topic: 저녁 초대
# [DIALOGUE]
#  #Person1#: 안녕하세요, 잭 있나요?
# #Person2#: 전데요.
# #Person1#: 잭! 나 로즈야.
# #Person2#: 안녕, 로즈. 어떻게 지내?
# #Person1#: 잘 지내, 고마워. 이번 주 토요일 저녁에 친구들 몇 명 초대했어. 너도 같이 올 수 있는지 궁금해서.
# #Person2#: 좋네. 몇 시에 가면 될까?
# #Person1#: 여섯 시 괜찮아?
#
# [SUMMARY]
#  로즈는 잭에게 전화하여 이번 주 토요일 저녁 식사에 초대한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_247
# topic: 면접 준비
# [DIALOGUE]
#  #Person1#: 저기요, 면접 보러 갈 때 뭐 입어야 할까요?
# #Person2#: 정장에 넥타이를 매는 게 좋을 것 같아요.
# #Person1#: 면접 중에 긴장할까 봐 걱정이에요.
# #Person2#: 걱정 마세요. 그냥 최선을 다해서 자신을 잘 표현하세요.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 면접에서 정장과 넥타이를 착용하고 자신을 잘 표현하라고 조언합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9260
# topic: 사업 전략 인터뷰
# [DIALOGUE]
#  #Person1#: 존, 동기부여에 대해 몇 가지 질문이 있어요. 당신이 지역 사람들과 함께 사업을 시작한 이유가 뭔가요?
# #Person2#: 음, 저는 항상 지역 산업을 돕기 위해 지역 사람들을 고용하려고 했어요. 하지만 이 지역은 스페인의 일부 지방처럼 실업률이 낮지 않아서, 지역 외부 사람들도 고용해야 해요.
# #Person1#: 관리 스타일은 어떠세요? 존, 엄격한 관리자이신가요?
# #Person2#: 아니요, 그렇게 생각하지 않아요. 저는 강한 성격을 가졌고, 관리자로서도 강한 편이긴 하지만, 사람들을 해고해야 할 때는 다섯 번, 열 번 더 기회를 주곤 해요.
# #Person1#: 앞으로의 계획은 무엇인가요? 무엇이 계속 당신을 움직이게 하나요?
# #Person2#: 사업적으로는, 두 주 전에 새 부사장이 회사에 합류했기 때문에 이제 고객과 신제품에 더 많은 시간을 쏟을 수 있을 것 같아요. 개인적으로는 삶의 질을 개선하기로 결심했고, 매주 수요일 오후에는 휴식을 취할까 해요. 이렇게 하면 교육 과정이나 더 여유로운 활동을 할 수 있을 것 같아요.
#
# [SUMMARY]
#  John은 지역 사람들과의 사업 시작 이유, 관리 스타일, 향후 사업 및 개인 생활 계획에 관해 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1430
# topic: 베를린행 비행기 티켓 구매
# [DIALOGUE]
#  #Person1#: 저기요, 베를린 가는 비행기가 언제 출발하나요?
# #Person2#: 40분 후, 11시에 출발합니다. 베를린 행 비행기는 두 시간마다 있습니다.
# #Person1#: 2등석 티켓은 얼마인가요?
# #Person2#: 죄송하지만, 현재 1등석 티켓밖에 남지 않았어요. 편도에 $350입니다.
# #Person1#: 알겠습니다. 다음 비행기 티켓 하나 주세요.
# #Person2#: 죄송하지만, 제가 티켓을 판매하지 않습니다. 저쪽에 있는 기계에서 구입하실 수 있어요.
# #Person1#: 알겠습니다. 그런데 게이트 번호가 몇 번인가요?
# #Person2#: 4번입니다. 복도를 따라 왼쪽으로 가시면 돼요.
# #Person1#: 감사합니다.
#
# [SUMMARY]
#  #Person1#는 베를린 행 비행기 시간을 묻고, #Person2#로부터 현재 이용 가능한 티켓과 가격 정보를 듣습니다. 티켓은 기계에서 구매할 수 있으며, 게이트 번호도 안내받습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10328
# topic: 코트 쇼핑
# [DIALOGUE]
#  #Person1#: 주, 이 코트 어때?
# #Person2#: 아, 조지. 이 색깔은 너무 화려하지 않아?
# #Person1#: 그럼 이건 어때?
# #Person2#: 음, 이 색은 너무 밝지 않아? 금방 더러워질 것 같아.
# #Person1#: 어이구, 주. 너 좀 까다롭네.
# #Person2#: 이거 사면 어때?
# #Person1#: 괜찮네. 한번 입어봐. 꽤 멋져 보이는데, 어깨 쪽이 좀 끼지 않아?
# #Person2#: 맞아. 더 큰 사이즈가 있는지 찾아보자. 음, 더 큰 건 없나 봐.
# #Person1#: 저기 저 판매원한테 가서 물어보는 게 어때? 우리를 도와줄 수 있을 거야.
#
# [SUMMARY]
#  주와 조지가 코트를 고르며 더 큰 사이즈가 있는지 판매원에게 물어보려 한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1740
# topic: 중요한 결정에 대한 논의
# [DIALOGUE]
#  #Person1#: 그녀가 그 소식을 전했을 때 뭐라고 했어?
# #Person2#: 나는 그냥 말문이 막혔어. 그리고 나중에, 그녀에게 그 중요한 결정을 다시 한 번 잘 생각해 보라고 했어. 단칼에 거절할 마음이 생기지 않더라고.
# #Person1#: 하지만 난 단호하게 잘못된 거라고 했어.
# #Person2#: 어떻게 그렇게 할 수 있어? 그녀는 따뜻함과 도움이 필요해.
#
# [SUMMARY]
#  #Person2#는 따뜻함과 도움이 필요한 소녀에게 #Person1#이 직설적으로 거부한 것에 동의하지 않습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6290
# topic: 친구와의 대화
# [DIALOGUE]
#  #Person1#: 안녕! 어떻게 지내?
# #Person2#: 잘 지내, 고마워. 넌 오늘 아침 어땠어?
# #Person1#: 나쁘지 않았어. 넌 어때? 오랜만에 본다.
# #Person2#: 맞아. 뉴욕에 다녀왔어. 어제 돌아왔거든.
# #Person1#: 재밌었겠다!
# #Person2#: 정말 재밌었어. 뉴욕은 정말 좋은 곳이야. 사진 몇 장 보여줄까?
# #Person1#: 좋아. 고마워, 나 사진 좋아해. 아, 근데 이제 가야 할 것 같아. 약속이 있거든. 좋은 하루 보내.
# #Person2#: 너도. 빨리 또 보자. 잘 가.
# #Person1#: 잘 가.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 뉴욕 여행을 다녀온 이야기를 하며 사진을 보여주겠다고 합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_12313
# topic: 영어 학습
# [DIALOGUE]
#  #Person1#: 리레이, 영어 수업은 어때요?
# #Person2#: 음, 재미는 있지만 쉽지 않아요.
# #Person1#: 뭐가 어려운가요?
# #Person2#: 여러 가지가 있는데, 특히 새 단어를 배우는 게요. 영어로 최대한 말하려고 노력하는데, 발음에서 실수하기도 해요.
# #Person1#: 영어 책 많이 읽어요?
# #Person2#: 많이 읽진 않아요. 사전 찾는 게 귀찮아서 듣는 걸 더 좋아해요.
# #Person1#: 듣는 것도 좋지만, 더 많이 읽어보는 것도 좋을 것 같아요. 그러면 새 단어 배우기가 더 쉬워질 거예요.
#
# [SUMMARY]
#  #Person1#은 리레이에게 영어 공부에 대해 물어봅니다. 리레이는 영어가 쉽지 않다고 답하며, 특히 새 단어를 배우는 것이 어렵다고 말합니다. #Person1#은 단어 학습을 위해 더 많은 독서를 제안합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1935
# topic: 발렌타인데이
# [DIALOGUE]
#  #Person1#: 오늘 날짜가 몇 일이야?
# #Person2#: 왜?
# #Person1#: 거리의 사람들 좀 봐봐. 다들 꽃다발을 들고 있어. 오늘 발렌타인데이야?
# #Person2#: 아, 맞다! 완전히 깜빡했네.
# #Person1#: 잭이랑 싸웠어?
# #Person2#: 아니, 근데 이제 잭이 곤란해지겠지. 남자친구가 있다는 건 발렌타인데이를 챙기라는 거잖아?
# #Person1#: 아이고, 너도 깜빡했잖아.
# #Person2#: 여자들은 이런 '중요한 날'을 깜빡해도 괜찮아, 근데 남자가 깜빡하는 건 용서할 수 없어.
# #Person1#: 너 핸드폰 벨소리 아니야?
# #Person2#: 아, 잭이야. 잠깐만.
# #Person1#: 와! 타이밍 좋네.
# #Person2#: 오늘 저녁에 같이 먹자고 하네. 같이 갈래?
# #Person1#: 에이! 삼각관계는 싫어!
# #Person2#: 그래서 뭐?
# #Person1#: 그냥 가! 오늘 발렌타인데이잖아!
#
# [SUMMARY]
#  #Person2#가 #Person1#에게 잭이 발렌타인데이를 잊어서 곤란해질 거라고 말하지만, 그때 잭이 전화를 걸어 저녁식사에 초대한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_927
# topic: 생일 저녁 준비
# [DIALOGUE]
#  #Person1#: 저녁 준비 도울게.
# #Person2#: 진짜? 농담하는 거지.
# #Person1#: 아니야. 네 생일이라 특별한 걸 해주고 싶어.
# #Person2#: 좋지. 그럼, 먼저 이 앞치마부터 입어.
# #Person1#: 좋아. 이제 어떻게 도와줄까, 자기야?
# #Person2#: 음, 어디 보자... 물 좀 끓여줘.
# #Person1#: 쉬운 거지. 눈 감고도 할 수 있어. (잠시 후) 다 됐어.
# #Person2#: 괜찮네. 자, 이제 냉장고에서 고기랑 감자 좀 꺼내.
# #Person1#: 감자는 몇 개 필요해?
# #Person2#: 세 개. 그리고 파프리카는 네 개 가져와.
# #Person1#: 알겠어. 좋아. 여기 있어.
# #Person2#: 이제 씻고, 감자랑 파프리카를 깍둑썰기 해줘.
# #Person1#: 감자 깎는 칼 어디 있어?
#
# [SUMMARY]
#  #Person1#은 #Person2#의 생일을 맞아 저녁 준비를 돕고 싶어 하고, #Person2#는 그에게 물을 끓이고, 재료를 꺼내고, 채소를 손질하도록 요청한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4023
# topic: 리얼리티 TV 프로그램
# [DIALOGUE]
#  #Person1#: 피곤해. 어제 늦게 자서 그래.
# #Person2#: 또 야근했어?
# #Person1#: 아니, 새로운 리얼리티 TV 프로그램 보다가 자정까지 깨어 있었어.
# #Person2#: 아이고, 아직도 그런 걸 보고 있어? 그냥 집에 갇혀서 아무것도 안 하는 사람들 이야기잖아. 처음엔 좀 재미있었는데, 요즘 같은 시대에 그런 프로그램을 보는 게 좀 이상해. 그 프로그램들은 사람들이 미디어의 관심을 받고 싶어하는 욕구를 충족시켜 주는 것 같아. 요즘은 다들 스타가 되고 싶어 하잖아.
# #Person1#: 그래도 그런 프로그램에 참여해서 다른 삶을 경험하거나 돈을 벌고 싶어 하는 사람들이 아직 있어.
# #Person2#: 아무튼 나는 그런 무명인들에게는 관심 없어. 그들의 유명세가 리얼리티 TV에 나왔다는 정도라면 말이야. 나는 진짜 재능 있는 사람들이 실제로 그만큼의 유명세를 얻는 걸 존경해. 그 사람들은 우리와 차원이 다르니까.
# #Person1#: 음, 나는 그렇게 생각하지 않아. 아마도 우리는 유명세가 뭔지 다시 생각해볼 필요가 있을지도 몰라.
#
# [SUMMARY]
#  #Person1#은 새로운 리얼리티 TV 프로그램을 자정까지 시청했다. #Person2#는 그런 프로그램들이 사람들이 미디어의 주목을 받고 싶어하는 욕구를 충족시키는 것 같아 관심이 없다고 한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5431
# topic: 음악 감상과 여행 이야기
# [DIALOGUE]
#  #Person1#: 와서 앉아. 뭐 마실래?
# #Person2#: 아, 네! 진토닉 한 잔 좋겠어.
# #Person1#: 올리브 좋아해? 아니면 감자칩이 좋아?
# #Person2#: 아, 올리브만 줘. 이 음악 뭐야?
# #Person1#: 마음에 들어? 아일랜드 음악이야.
# #Person2#: 너무 좋다! 이 CD 어디서 샀어?
# #Person1#: 음, 몰 안에 있는 CD 가게에서 산 것 같아. 거기 가본 적 있어?
# #Person2#: 응, 거기서 물건 많이 사. 좋은 가게지?
# #Person1#: 맞아. 헤이, 우리 아일랜드 여행 사진 좀 있어. 보고 싶어?
# #Person2#: 왜 안 보겠어? 보고 싶어!
#
# [SUMMARY]
#  #Person1#은 #Person2#에게 음료를 준비해주고, 음악 CD를 어디서 구매했는지 설명한다. 그리고 나서 #Person1#은 #Person2#에게 아일랜드 여행 사진을 함께 보자고 제안한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2391
# topic: 개인 정보 유출
# [DIALOGUE]
#  #Person1#: 아, Mary. 그걸 왜 했어?
# #Person2#: 뭘 했다는 거야?
# #Person1#: 무슨 말인지 알잖아. 왜 Mrs. Jones한테 내가 얼마나 벌게 될지 말했다고?
# #Person2#: 미안해, Frank.
# #Person1#: 그래, 근데 그분은 모든 사람한테 수다 떨잖아.
# #Person2#: 정말 미안해. 생각 없이 그랬어. 너무 신이 나서 그랬나봐.
# #Person1#: 뭐, 이제 됐지 뭐. 어차피 크게 상관없을지도. 결국 다들 알게 될 거야. 이 동네 사람들 다들 호기심 많아.
# #Person2#: 첫 직장 치고 정말 많은 돈이니까.
#
# [SUMMARY]
#  #Person1#은 Mary가 자신의 급여를 Mrs. Jones에게 말한 것에 대해 불만을 드러냈다. Mrs. Jones는 소문이 빠르게 퍼지는 성향이 있다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5611
# topic: James Dean의 전기
# [DIALOGUE]
#  #Person1#: 안녕하세요, 전설적인 인물들의 삶을 소개하는 오늘 밤 방송에 오신 것을 환영합니다. 오늘의 주제는 당시 젊은이들의 영웅이었던 배우 James Dean입니다. Edward Murray는 Dean의 새로운 전기를 쓴 저자입니다. 안녕하세요, Edward.
# #Person2#: 안녕하세요, Tina.
# #Person1#: Edward, Dean의 어린 시절에 대해 아는 것을 말씀해 주세요.
# #Person2#: 그는 1931년에 인디애나에서 태어났지만, 부모님이 그가 5살 때 캘리포니아로 이사했습니다. 그러나 그는 오래 그곳에 있지 않았습니다. 엄마가 4년 후에 돌아가셨거든요. Jimmy의 아버지는 그 후 그를 이모와 함께 살게 하려고 다시 인디애나로 보냈습니다.
# #Person1#: 그래서 어떻게 연기에 발을 들였나요?
# #Person2#: 처음에는 고등학교에서 연극을 했습니다. 그런 다음 캘리포니아의 대학에 가서 연기에 진지하게 임하게 되었죠. 1951년, 그는 더 많은 무대 연기를 하기 위해 뉴욕으로 갔습니다.
# #Person1#: 그럼 영화 경력은 언제 본격적으로 시작되었나요?
# #Person2#: 1955년입니다. 그의 첫 주연작이 '에덴의 동쪽'이었죠. 굉장했습니다. Dean은 엄청난 성공을 거두었어요. 그러나 그를 정말 유명하게 만든 영화는 두 번째 작품인 '이유 없는 반항'이었습니다. 이는 사회에 적응하지 못하는 십대에 관한 영화였죠.
# #Person1#: 그래서 그는 몇 편의 영화를 더 찍었나요?
# #Person2#: 단 한 편 더 찍었어요. 그러고 나서 1955년에 캘리포니아에서 교통사고로 세상을 떠났습니다.
# #Person1#: 정말 비극적이네요! 단 3편의 영화만 찍었다니. 그런데 어떻게 그는 오늘날까지 전설로 남은 걸까요?
# #Person2#: 아마도 그의 외모, 연기력, 짧은 삶, 그리고 영화 속에서 맡았던 캐릭터의 유형 때문일 겁니다. 많은 젊은이들이 그를 미국 청소년의 상징으로 여겼어요.
#
# [SUMMARY]
#  Edward는 Tina에게 Dean이 1931년 인디애나에서 태어나 캘리포니아와 인디애나에서 살았다고 설명합니다. 그는 대학 시절에 연기에 진지하게 임하게 되었고, 1951년에 무대 연기를 위해 뉴욕으로 이주했습니다. Dean은 1955년에 사망했으며 단 3편의 영화로 전설이 되었습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4739
# topic: 온라인 쇼핑의 장단점
# [DIALOGUE]
#  #Person1#: 혹시 온라인 쇼핑 해본 적 있어?
# #Person2#: 아니, 전혀 없어. 난 물건을 사기 전에 직접 보고 만지는 걸 좋아해. 특히 옷이나 신발 같은 건 말이야.
# #Person1#: 맞아. 직접 봐야 믿음이 가지.
# #Person2#: 친구들 중에 광고랑 완전히 다른 물건을 받았다는 사람들도 있더라고.
# #Person1#: 그런 경우 있지. 품질을 꼼꼼히 확인하지 않으면 사기 당할 수도 있고, 특정 상점이 갑자기 사라지기도 해.
# #Person2#: 게다가 온라인 결제가 항상 안전하지 않다고도 하더라. 해커들이 아이디나 비밀번호를 훔쳐갈 수도 있으니까.
# #Person1#: 이런 문제를 해결하려고 몇 가지 조치가 이루어졌다고 하던데. 온라인 결제가 이전보단 훨씬 안전해졌다고는 하지만, 완전히 안전하다고 느끼지는 않아.
# #Person2#: 맞아. 그래서 난 오프라인 쇼핑만 해.
# #Person1#: 나도 그래. 가끔 온라인에서 정보 좀 찾아보고, 그다음에 실제 매장에서 사.
# #Person2#: 좋은 생각이야.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 온라인 쇼핑의 단점, 특히 안전 문제와 제품의 품질 문제에 대해 이야기하며 둘 다 오프라인 쇼핑을 선호한다고 말한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5825
# topic: 집안 정리
# [DIALOGUE]
#  #Person1#: Michelle, 우리 가기 전에 좀 정리하는 거 도와줄래?
# #Person2#: 물론이지. 이 컵은 어디에 둘까?
# #Person1#: 어떤 컵?
# #Person2#: 빨간색.
# #Person1#: 테이블 위에 둬.
# #Person2#: 이 과일은?
# #Person1#: 그거는 냉장고에 넣어.
# #Person2#: 그리고 저 연필들은? 그건 어떻게 할까?
# #Person1#: 그거는 위층에 가져가서 침실에 둬.
# #Person2#: 이 펜은?
# #Person1#: 그건 나한테 줘. 내가 써야 해.
# #Person2#: 저기 있는 종이는 어떻게 할까?
# #Person1#: 그건 버려도 돼. 이제 필요 없어.
# #Person2#: 쓰레기가 가득 찼네.
# #Person1#: 그럼, 봉지에 넣어서 밖에 내다줘.
# #Person2#: 알겠어. 이제 뭐 할까?
# #Person1#: 이제 끝난 것 같아. 불 끄고 문 닫아줄래?
# #Person2#: 그래.
#
# [SUMMARY]
#  #Person1#는 Michelle에게 떠나기 전에 집을 정리하는 것을 부탁했고, 함께 물건을 정리했습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9367
# topic: 아파트 찾기
# [DIALOGUE]
#  #Person1#: 안녕하세요, 어떻게 지내세요?
# #Person2#: 꽤 괜찮아요. 오늘 뭐하고 지내세요?
# #Person1#: 아파트를 구하고 있어요.
# #Person2#: 작은 아파트랑 큰 아파트 중 어떤 거 찾고 계세요?
# #Person1#: 방 두 개짜리 아파트를 찾고 싶어요.
# #Person2#: 신문에서 광고 찾아보고 계세요?
# #Person1#: 네, 그리고 도움을 줄 수 있다고 하는 부동산 중개인 전화번호도 받았어요.
# #Person2#: 어디에 아파트를 구하고 싶으세요?
# #Person1#: 살 수 있는 가격이면서, 자전거나 걸어서 출퇴근할 수 있는 곳이라면 상관없어요. 딱히 까다로운 건 없어요.
# #Person2#: 개가 있지 않나요?
# #Person1#: 네, 있어요.
# #Person2#: 그럼 찾기가 좀 더 어려울 수도 있겠네요.
# #Person1#: 맞아요. 본 곳들 중 많은 곳에서 애완동물을 허용하지 않더라고요.
# #Person2#: 우리 사촌 데이브가 개 두 마리 키워요. 그 건물에 빈 아파트가 있는지 물어볼게요.
# #Person1#: 고마워요. 뭐라고 하는지 알려주세요.
# #Person2#: 물론이죠.
#
# [SUMMARY]
#  #Person1#은 방 두 개짜리 아파트를 찾고 있습니다. #Person1#는 개를 키우고 있어서 아파트를 찾기가 더 어렵습니다. #Person2#의 사촌은 개 두 마리를 키우고 있으며, 그의 건물에 빈 아파트가 있는지 물어볼 것입니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4404
# topic: 강당 찾기
# [DIALOGUE]
#  #Person1#: 저기요, 강당이 어디 있는지 아세요?
# #Person2#: 저도 잘 모르겠어요. 친구가 거기서 기다리고 있어서 저도 찾고 있는 중이에요. 아침에 거기서 문학 수업을 들었다고 했거든요. 이쪽인 것 같아요.
# #Person1#: 같이 가도 될까요?
# #Person2#: 물론이죠. 어떤 수업 듣고 있으세요?
# #Person1#: 경제학 입문 수업 들어요. 수강생이 많다고 들었어요.
# #Person2#: 네, 제 룸메이트가 지난 학기에 들었는데, 강의실에 300명 넘게 있었다고 하더라고요.
#
# [SUMMARY]
#  #Person1#이 강당 가는 길을 #Person2#에게 물어보지만, #Person2#도 강당을 찾고 있는 중입니다. 둘은 함께 강당을 찾으러 갑니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6148
# topic: 패스트푸드 주문
# [DIALOGUE]
#  #Person1#: 맥도널드에 오신 걸 환영합니다. 주문 도와드릴까요?
# #Person2#: 엑스트라 밸류 밀 하나랑 팥 파이 하나, 야채 샐러드 하나 주세요.
# #Person1#: 음료는 어떤 걸로 드릴까요?
# #Person2#: 뜨거운 오렌지 주스로 주세요.
# #Person1#: 주문 이걸로 다 되셨나요?
# #Person2#: 네, 그게 전부입니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#가 맥도널드에서 음식과 음료를 주문하도록 돕습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5349
# topic: 영어 학습
# [DIALOGUE]
#  #Person1#: 나는 영어 배우는 게 너무 힘들어. 너는 왜 그렇게 쉬워 보이니?
# #Person2#: 네가 어려움을 겪고 있는지 몰랐어. 아마 내가 이미 두 가지 언어를 해서 더 쉬운 것 같아. 근데 나도 정말 열심히 해.
# #Person1#: 나도 항상 숙제하고 수업도 가. 다른 도움 될 만한 게 있을까?
# #Person2#: 음, 신문을 읽어보는 건 어때? 그리고 나는 기회가 되면 항상 미국인과 대화해. 물론 가끔 힘들지만.
# #Person1#: 근데 미국인을 어떻게 만나? 나도 다른 유학생들밖에 몰라.
# #Person2#: 점심 때 미국인 옆에 앉아 보거나, 아니면 누군가를 저녁에 초대하는 건 생각해 본 적 있어?
# #Person1#: 좋은 생각이네. 근데 영어로 말하는 게 좀 부끄러워.
# #Person2#: 시도해 보지 않으면 배울 수 없어. 나라면, 너의 영어 선생님과 이야기해 볼 거야. 선생님이 좋은 아이디어를 줄 수도 있어.
#
# [SUMMARY]
#  #Person1#는 영어를 배우는 데 어려움을 겪고 있다. #Person2#는 신문 읽기, 미국인과 대화하기, 그리고 #Person1#의 영어 선생님에게 도움을 요청할 것을 제안한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3544
# topic: 저녁 준비
# [DIALOGUE]
#  #Person1#: 밥 먹자!
# #Person2#: 아, 배고파 죽겠어. 엄마 어디 계셔?
# #Person1#: 엄마가 오늘 몸이 안 좋으셔서 내가 저녁 준비했어.
# #Person2#: 그런데 이게 뭐야... 그 냄새는 또 뭐고?
# #Person1#: 피자야. 우리 가족 옛날 레시피 따라서 해봤어.
# #Person2#: 잠깐 보여줘봐... 어, 페이지가 빠졌잖아!
# #Person1#: 아, 음, 저기, 레시피의 두 번째 페이지를 못 찾았어. 하지만 걱정 마, 나 집안일 경험 많거든.
# #Person2#: 나 한 번 먹어볼게. 어, 너무 짜고 탄 것 같아.
# #Person1#: 음, 우리 나가서 저녁 먹는 게 나을 것 같아.
#
# [SUMMARY]
#  엄마가 오늘 몸이 안 좋으셔서 #Person1#이 저녁을 준비했습니다. #Person2#는 #Person1#의 피자가 너무 짜고 탔다고 말합니다. 결국 #Person1#은 외식하기로 결정합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1261
# topic: 직업 선택
# [DIALOGUE]
#  #Person1#: David, 졸업하고 뭐 하고 싶어?
# #Person2#: '베스트 커리어 리스트' 중 하나를 골라서 공무원이 돼야 할까 싶어. 너는 어떻게 생각해?
# #Person1#: 인기 있는 직업이긴 하지. 근데 내 생각에 너는 그 리스트에서 고르기보다는, 너의 흥미, 가치관, 그리고 능력을 고려해야 한다고 생각해.
# #Person2#: 모르겠어! 전에 그런 건 생각해 본 적 없고 그냥 직업 찾는 게 쉬울 거라고 생각했던 것 같아.
# #Person1#: 너는 진로 상담사에게 조언을 받고 나서 결정하는 게 좋을 것 같아.
#
# [SUMMARY]
#  David는 공무원이 될 생각을 하고 있으며, #Person1#은 진로 상담사에게 상담을 받을 것을 권장합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7532
# topic: 여행 가방 분실
# [DIALOGUE]
#  #Person1#: 여러분, 저희는 지금 샌프란시스코로 향하고 있습니다.
# #Person2#: 저기요, 승무원님.
# #Person1#: 네, 손님. 무슨 일이신가요?
# #Person2#: 큰일이에요.
# #Person1#: 멀미 나세요?
# #Person2#: 아니요. 제 여행 가방을 안 가지고 왔다는 걸 이제야 알았어요.
# #Person1#: 걱정 마세요, 손님. 가방이 어떻게 생겼는지 말씀해 주시겠어요?
# #Person2#: 파란색 작은 가죽 가방인데, 제 이름과 주소가 적혀 있어요. 가방 벨트에는 갈색 농구공 장난감이 달려 있고, 검은색 지갑도 안에 있어요.
# #Person1#: 마지막으로 가방을 어디서 보셨는지 기억나세요?
# #Person2#: 어... 공항에서 수하물 맡길 때 항공사 카운터에 놔두고 온 것 같아요.
# #Person1#: 그러면 제가 공항 직원들에게 연락해서 아직 거기에 있는지 확인해 볼게요.
# #Person2#: 도와주셔서 감사합니다.
# #Person1#: 천만에요.
#
# [SUMMARY]
#  #Person1#이 #Person2#의 여행 가방이 항공사 카운터에 있는지 확인하기 위해 공항 직원에게 연락할 것입니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1396
# topic: 얼음물 배달
# [DIALOGUE]
#  #Person1#: 안녕하세요. John ' s Distribution입니다. 어떻게 도와드릴까요?
# #Person2#: 네, 얼음물 좀 배달 받고 싶어요.
# #Person1#: 그럼 지금 아예 없으세요?
# #Person2#: 아니요, 조금 있긴 한데 긴 주말 내내는 부족할 것 같아요.
# #Person1#: 알겠습니다. 내일 사람을 보내서 배달해드리겠습니다.
# #Person2#: 감사합니다.
# #Person1#: 별말씀을요.
#
# [SUMMARY]
#  #Person2#는 얼음물이 필요하며, #Person1#은 내일 배달하기로 했습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_518
# topic: 외출 준비
# [DIALOGUE]
#  #Person1#: 내 새 빨간색 넥타이 어디 뒀지?
# #Person2#: 네 다른 넥타이들이랑 찬장에 있을 거야.
# #Person1#: 초록색 하나랑 갈색 몇 개밖에 없는데, 빨간 건 없어.
# #Person2#: 여기 네 서랍에 있네. 네가 집에 가져왔을 때 넣어뒀던 것 같아.
# #Person1#: 그런가 봐. 우리 빨리 가야 할 것 같아, 안 그러면 늦겠어. 스미스 부부가 7시에 오라고 했거든.
# #Person2#: 아, 지금 6시 24분이네. 수가 아직 애들 봐주러 안 왔네.
# #Person1#: 수는 6시 40분에 올 거야. 그래도 그때까지 도착할 시간은 충분해.
# #Person2#: 오늘 밤에 누가 또 오는데?
# #Person1#: 브라운 부부랑 프랭크 부부. 그리고 존슨 부인의 여동생도 있을 거야.
# #Person2#: 음, 우리 이제 내려가자. 수가 곧 올 거야.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 급하게 준비 중이다. #Person1#이 빨간색 넥타이를 찾을 수 없자, #Person2#가 서랍에서 찾아준다. 그들은 아이들을 돌봐줄 수가 오기를 기다리고 있다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_434
# topic: 호텔 예약 확인
# [DIALOGUE]
#  #Person1#: 안녕하세요. 어떻게 도와드릴까요?
# #Person2#: 네, 예약한 방이 있는데요. Mona White 이름으로요. 지난주에 전화했어요.
# #Person1#: 잠시만 기다려 주세요, White 님. 네, 맞아요. 두 개의 싱글룸이죠? 402호와 403호로 예약해두었습니다.
# #Person2#: 그 방들 조용한가요?
# #Person1#: 아, 길가 쪽이긴 하지만 전망은 아주 좋아요.
# #Person2#: 저희 조용한 방으로 부탁드릴게요.
# #Person1#: 알겠습니다.
#
# [SUMMARY]
#  Mona White는 예약한 방의 조용함을 요청하고, #Person1#이 이를 확인해 줍니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1983
# topic: 첫 만남
# [DIALOGUE]
#  #Person1#: 안녕하세요!
# #Person2#: 네, 안녕하세요!
# #Person1#: 이름이 뭐예요?
# #Person2#: 제 이름은 난두예요.
# #Person1#: 난두, 이름 어떻게 쓰나요?
# #Person2#: 네, 제 이름은 N-A-N-D-U로 씁니다.
# #Person1#: 아, 네. 좋은 이름이네요, 난두. 그런데 어디서 오셨어요?
# #Person2#: 저는 마드라스에서 왔어요.
#
# [SUMMARY]
#  #Person1#과 난두가 처음 만납니다. 난두는 자신의 이름 철자를 알려주고 마드라스 출신이라고 말합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9384
# topic: 연극 평가
# [DIALOGUE]
#  #Person1#: 연극 어땠어?
# #Person2#: 너무 지루하고, 연출도 별로였어.
# #Person1#: 맞아, 연기도 좀 더 나을 수 있었을 것 같아.
# #Person2#: 그래도 의상하고 무대 장치는 멋지더라.
# #Person1#: 그건 인정해. 하지만 전체적으로 난 별로였어.
# #Person2#: 그럼 다음엔 뮤지컬 코미디를 보러 가자. 지난번에 본 건 정말 좋았잖아.
# #Person1#: 맞아, 장면 전환이 자주 있어서 나는 그런 다양함이 좋더라고.
# #Person2#: 나도 그래. 같은 무대 장치를 계속 보고 있는 건 좀 싫지.
#
# [SUMMARY]
#  #Person2#는 연극이 지루하다고 느꼈고, #Person1#도 그다지 좋지 않았다고 말합니다. 다음번에는 장면 전환이 많은 뮤지컬을 보러 가자고 #Person2#가 제안합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8634
# topic: 음식 픽업 주문
# [DIALOGUE]
#  #Person1#: 여보세요, 베이징 레스토랑입니다. 무엇을 도와드릴까요?
# #Person2#: 안녕하세요. 주문하려고 하는데요.
# #Person1#: 픽업인가요, 아니면 배달인가요?
# #Person2#: 픽업이요.
# #Person1#: 어떤 걸 주문하시겠어요?
# #Person2#: 여기 메뉴판이 있어요. 메뉴판에서 각 번호로 주문할게요.
# #Person1#: 네, 괜찮습니다.
# #Person2#: 17번, 23번, 그리고 24번 주문할게요.
# #Person1#: 어떤 사이즈로 드릴까요?
# #Person2#: 중간 사이즈로 부탁드려요.
# #Person1#: 언제쯤 오실 건가요?
# #Person2#: 한 시간 정도 후에 갈게요.
# #Person1#: 알겠습니다. 도착하시면 음식이 준비되어 있을 겁니다. 주문 감사합니다.
#
# [SUMMARY]
#  #Person2#는 베이징 레스토랑에 전화로 픽업 주문을 하고 한 시간 후에 도착할 것이라고 #Person1#에게 말합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3461
# topic: 야드 세일
# [DIALOGUE]
#  #Person1#: 엘리자베스, 무슨 질문이야?
# #Person2#: 저기, 야드 세일이 뭔지 좀 설명해 줄 수 있어요?
# #Person1#: 간단히 말해서, 집 마당에서 헌 물건들을 파는 세일이야.
# #Person2#: 거기서 뭐 살 수 있어요?
# #Person1#: 책, 레코드, 컵, 가구 같은 거. 정말 다양하게 있어.
# #Person2#: 왜 미국 사람들은 중고 물건을 사는 걸 좋아하죠?
# #Person1#: 주로 돈을 절약하려고 그래. 또 보물 찾는 재미도 있지.
# #Person2#: 아, 그렇군요.
# #Person1#: 사실 많은 서양 사람들이 다른 사람의 물건에 관심이 많아. 부자들도 중고 물건에서 보물을 찾는 경우가 많아.
# #Person2#: 이해했어요. 고맙습니다, Mr. Green. 큰 도움이 됐어요.
# #Person1#: 천만에요.
#
# [SUMMARY]
#  Mr. Green은 엘리자베스에게 야드 세일의 개념과 그곳에서 구매 가능한 물건, 미국인이 중고 물건을 선호하는 이유를 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5697
# topic: 계약 검토
# [DIALOGUE]
#  #Person1#: 계약에 대해 궁금한 점이 있으시면 언제든지 말씀해 주세요. 제가 답변해 드릴게요.
# #Person2#: 지금 당장은 떠오르는 게 없지만, 서명하기 전에 계약 조항을 한 번 더 검토하고 싶어요.
#
# [SUMMARY]
#  #Person1#은 계약에 대한 질문이 있으면 언제든지 답변하겠다고 했고, #Person2#는 서명 전에 계약을 검토하고 싶다고 말했습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10125
# topic: 취업 준비
# [DIALOGUE]
#  #Person1#: 요즘 취업 준비는 어떻게 돼가고 있어?
# #Person2#: 글쎄, 며칠 전부터 취업 준비를 시작했어.
# #Person1#: 그렇구나. 관심 있는 곳은 찾아봤어?
# #Person2#: 내 분야에서는 몇 군데밖에 못 찾았어.
# #Person1#: 어떤 직업을 찾고 있는데?
# #Person2#: 음향 기술 쪽에서 일을 찾으려고 하고 있어.
# #Person1#: 그 분야는 수요가 그렇게 많지는 않지 않아?
# #Person2#: 아쉽게도 그래. 만약 음향 쪽에서 일을 찾기 힘들면 관광 쪽도 생각하고 있어.
# #Person1#: 좋은 생각이야. 너 관광 산업 쪽 경험 많잖아?
# #Person2#: 맞아.
# #Person1#: 그런데 말이야, 오늘 아침 신문에서 너한테 맞을 만한 일자리 하나 봤어.
# #Person2#: 진짜? 어떤 일이야?
# #Person1#: 채용 대행사에서 일하는 자리야.
# #Person2#: 흥미롭네. 거기서 나를 채용할까?
# #Person1#: 너 구직 경험 많잖아. 딱 맞는 사람일 것 같은데?
# #Person2#: 맞아, 연락해보고 면접 볼 수 있는지 확인해봐야겠어. 혹시 정보 좀 있어?
# #Person1#: 물론이지. 광고란 중간에 빨간 펜으로 동그라미 친 게 있어. 행운을 빌어!
#
# [SUMMARY]
#  #Person2#는 음향 기술 분야에서 일자리를 찾고 있지만 몇 군데밖에 찾지 못했습니다. 또한 관광 분야에서 일할 수도 있습니다. #Person1#은 채용 대행사에서 일자리를 추천하며, #Person2#는 흥미를 보입니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3742
# topic: 길 안내
# [DIALOGUE]
#  #Person1#: 저기요, 마틴 루터 킹 학교가 어디에 있나요?
# #Person2#: 뭐라고요?
# #Person1#: 마틴 루터 킹 학교가 어디에 있나요?
# #Person2#: 잠시만요, 제가 차를 세울게요. 자, 다시 말씀해 주세요.
# #Person1#: 마틴 루터 킹 학교가 어디에 있나요?
# #Person2#: 음, 이 길을 따라가다가 우회전하세요.
# #Person1#: 잠시만요. 지도가 있어요.
# #Person2#: 좋아요. 보세요, 우리가 여기 있고 학교는 저기예요.
# #Person1#: 알겠어요. 이 길을 따라가면 되네요.
# #Person2#: 그리고 우회전하세요.
# #Person1#: 우회전하고 직진이네요.
# #Person2#: 마틴 루터 킹 학교는 은행 옆에 있어요.
# #Person1#: 감사합니다.
# #Person2#: 천만에요.
#
# [SUMMARY]
#  #Person2#가 #Person1#에게 마틴 루터 킹 학교로 가는 길을 안내합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3473
# topic: 저녁 초대
# [DIALOGUE]
#  #Person1#: 저녁에 초대하고 싶은데, 시간 어때? 그리고 어떤 음식을 좋아해?
# #Person2#: 좋지. 나는 매운 샤브샤브가 먹고 싶어. 왜 갑자기 초대하는 거야?
# #Person1#: 지난주에 일 도와줘서 고맙다는 뜻이야. 네가 그렇게 친절하지 않았더라면 공항에 부모님 마중 나가는 것도 못 했을 거야. 아주 큰 도움이 되었어. 정말 고마워.
# #Person2#: 즐거운 마음으로 도와줬어. 오늘 저녁은 어때? 지금 너무 배가 고프네.
# #Person1#: 좋아, 시내에 맛있는 샤브샤브 가게가 있는데 거기 갈까? 음식도 꽤 매워.
# #Person2#: 좋아, 그래 네 뜻대로 하자. 퇴근하고 내려가서 만나자.
#
# [SUMMARY]
#  #Person1#은 지난주에 큰 도움을 준 #Person2#에게 감사를 표하기 위해 오늘 저녁에 초대합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5773
# topic: 티켓 예약
# [DIALOGUE]
#  #Person1#: 안녕하세요. 어떻게 도와드릴까요?
# #Person2#: 안녕하세요. 8월 2일 홍콩행 예약을 하고 싶습니다.
# #Person1#: 잠시만요, 손님. 죄송하지만 그날은 예약 가능한 티켓이 없습니다. 하지만 다음 날 홍콩행 비행기가 있습니다.
# #Person2#: 출발 시간이 어떻게 되나요?
# #Person1#: 아침 9시 12분 비행기와 오후 2시 비행기가 있습니다.
# #Person2#: 그럼 아침 비행기는 홍콩에 언제 도착하나요?
# #Person1#: 10시 20분에 도착합니다.
# #Person2#: 좋아요. 그 비행기로 예약 부탁드립니다.
# #Person1#: 알겠습니다, 손님. 비행 이틀 전 정오까지 티켓을 꼭 재확인해 주세요. 그렇지 않으면 예약이 자동으로 취소됩니다.
# #Person2#: 네, 알고 있습니다. 요금이 어떻게 되나요?
# #Person1#: 500달러입니다. 공항과 시내 간의 지상교통 요금은 포함되어 있지 않습니다.
# #Person2#: 알겠습니다. 왕복 요금은 두 배인가요?
# #Person1#: 네, 맞습니다. 티켓 구입 시 유효한 여행 서류를 꼭 지참해 주세요.
# #Person2#: 네, 알겠습니다.
#
# [SUMMARY]
#  #Person2#는 8월 2일 홍콩행 예약을 원했지만 티켓을 구할 수 없었습니다. #Person1#은 #Person2#가 다음 날 아침 비행기로 예약할 수 있도록 도와주고, 티켓 재확인을 요청했습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8847
# topic: 이별 위로
# [DIALOGUE]
#  #Person1#: 왜 이렇게 조용해?
# #Person2#: 여자친구가 방금 나랑 헤어졌어.
# #Person1#: 지금 많이 힘들겠다.
# #Person2#: 응.
# #Person1#: 나도 첫 이별이 생각나. 세상에서 제일 최악의 기분이었어. 세 달 동안 매일 울었어. 그러다가 천천히 나아지더라. 너도 괜찮아질 거야.
# #Person2#: 너도 그런 적 있어?
# #Person1#: 응. 너무 선명하게 기억나. 그 고통이 기억을 더 쉽게 해주지. 지금 정말 아프겠지만, 이별은 많은 사람들이 겪는 일이거든.
# #Person2#: 근데 너무 아파.
# #Person1#: 그게 아프긴 해, 하지만 일시적인 거야. 이 고통이 사라지면 다른 사람들을 만나게 될 거야.
# #Person2#: 만약 내가 다른 사람을 만나고 싶지 않으면?
# #Person1#: 마음이 바뀔 거야. 세상의 모든 사람들을 봐, 다들 헤어지고 다시 시작하잖아. 이걸 빨리 이해하면 더 빨리 회복될 거야.
# #Person2#: 맞아.
# #Person1#: 너도 아직 그녀에 대한 감정이 남아 있을 거라는 건 아는데, 안 좋았던 점들을 떠올려 봐. 그녀가 그렇게 잘 대해주진 않았잖아. 그런 사람이랑 평생을 함께 하고 싶어?
# #Person2#: 맞아. 얘기해줘서 고마워.
# #Person1#: 이따가 전화할게. 같이 좀 놀러가자. 사람들과 함께 있는 게 좋아.
# #Person2#: 그래. 이따가 얘기하자.
#
# [SUMMARY]
#  #Person2#의 여자친구가 그와 헤어졌습니다. #Person1#은 유사한 경험을 공유하면서 #Person2#에게 모든 사람들이 이별을 겪고 극복한다고 이야기합니다. #Person1#은 #Person2#의 회복을 격려하며 함께 놀러 가자고 초대합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6157
# topic: 집 판매 논쟁
# [DIALOGUE]
#  #Person1#: 자기, 우리 이 집 같이 산 건 알겠는데, 꾸미는 데 너무 돈이 많이 들 것 같아. 이 집 파는 게 좋을 것 같아.
# #Person2#: 안 돼, Nathan. 내가 보기엔 우리가 이 아파트를 정말 좋은 시기에 샀어. 부동산 가격이 오를 거야. 1, 2년 후면 값이 많이 올라 있을걸.
# #Person1#: 근데 가구나 인테리어에 너무 돈을 많이 써야 할 거야. 이미 가구가 있는 집을 더 싸게 살 수 있잖아.
# #Person2#: 그래서 이 집이 마음에 안 들어? 우리가 여기 처음 봤을 때 멋지다고 생각했잖아.
# #Person1#: 그건 자기만 좋아했던 거야, 자기야.
# #Person2#: 아, 왜 그때 얘기 안 했어? 그래도 좋은 매물 잡은 거라고 생각해.
#
# [SUMMARY]
#  Nathan은 꾸미는 비용이 많이 들어 집을 팔고 싶어 하지만, #Person2#는 아파트를 좋은 시기에 샀고 가격이 오를 것이라며 매물 구입이 좋은 선택이었다고 주장합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2085
# topic: 잘못 걸린 전화
# [DIALOGUE]
#  #Person1#: 여보세요?
# #Person2#: 여보세요? Bernie 씨, 저는 Lisa입니다. 방해가 아니길 바라요. 따님 소식을 들었어요. 그분이 정말 그리울 거예요.
# #Person1#: 죄송하지만, 잘못 거신 것 같아요. 저는 Bernie 씨가 아니에요.
# #Person2#: 뭐라고요? 이상하네요. 번거롭게 해드려서 죄송해요.
# #Person1#: 괜찮아요.
#
# [SUMMARY]
#  Lisa가 Bernie에게 전화를 하려 했으나 다른 사람에게 잘못 연결되었습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4718
# topic: 저녁 준비
# [DIALOGUE]
#  #Person1#: 오늘 저녁 뭐 먹을 거야?
# #Person2#: 네가 정해 봐.
# #Person1#: 너 오늘 저녁 안 만들 거야?
# #Person2#: 너는 요리 안 하잖아. 항상 내가 하잖아.
# #Person1#: 네가 요리를 더 잘해서 그런 거지.
# #Person2#: 아, 정말. 오늘은 네가 좀 해야 해.
# #Person1#: 그러니까 네가 저녁 차리라는 거야?
# #Person2#: 오늘 너무 힘들었어. 오늘 저녁은 네가 해주면 안 될까?
# #Person1#: 그럼 내가 저녁 준비할게, 걱정 마.
# #Person2#: 나는 잠깐 쉬러 갈게.
# #Person1#: 다 되면 깨울게, 알았지?
# #Person2#: 고마워.
#
# [SUMMARY]
#  #Person2#는 오늘 일이 힘들어서 요리하기 싫어합니다. #Person1#은 평소 요리를 하지 않지만 오늘은 요리를 해주기로 합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1739
# topic: 컨퍼런스 참석
# [DIALOGUE]
#  #Person1#: 아, 미쉘 안녕. 너를 만나고 싶었어. 잘 지냈어? 가족들은 잘 지내고 있어?
# #Person2#: 안녕하세요, 캠벨 씨. 저는 잘 지내고 있고, 잭도 잘 지내요. 캠벨 씨는 어떻게 지내세요?
# #Person1#: 저도 잘 지내고 있어. 아침에 네 보고서 받았어. 고마워. 오늘 컨퍼런스에 참석하니?
# #Person2#: 네, 오후 4시에 출발해요.
# #Person1#: 좋네, 그때 더 이야기할 수 있겠다. 이번 분기 수치들이 아주 좋아 보여.
# #Person2#: 네, 저도 그렇게 생각해요.
# #Person1#: 난 컨퍼런스에서 광고 예산에 대해 논의하려고 해요. TV 광고를 계속할 필요는 없다고 생각해.
#
# [SUMMARY]
#  캠벨 씨와 미쉘은 미쉘의 보고서와 광고 예산에 대해 논의하기 위해 컨퍼런스에 참석할 예정이다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8267
# topic: 음식 주문
# [DIALOGUE]
#  #Person1#: 정말 멋지네요, Madame Culot.
# #Person2#: 네, 정말 괜찮죠. 외국 손님들이 다들 좋아하시더라고요. 음식이 정말 잘 준비되어 있으니, 메뉴 고르실 때 필요하신 거 있으면 말씀해 주세요.
# #Person1#: 감사합니다. 음, 테린에 대해 좀 설명해 주실래요?
# #Person2#: 네, 테린은 일종의 고기 파테예요. 고기를 갈아서 만든 건데, 듣기엔 별로일 것 같지만 실제로는 정말 맛있어요.
# #Person1#: 음, 다음에 먹어볼게요.
# #Person2#: 라비올리도 괜찮아요. 중국식 만두와 비슷한데, 소스가 아주 맛있어요.
# #Person1#: 괜찮네요. 메인 요리로는 양고기를 할게요. 뭐가 같이 나오나요?
# #Person2#: 프렌치 프라이 아니면 간단히 삶은 감자를 선택하실 수 있어요.
# #Person1#: 그럼 감자로 할게요. 당신은 뭐 드세요?
# #Person2#: 전 항상 먹던 걸로 할 거예요. 여기 생선이 괜찮거든요. 와인 하실래요?
# #Person1#: 아, 네. 그러면 좋겠네요.
#
# [SUMMARY]
#  Madame Culot은 #Person1#에게 테린이 무엇인지 설명하고 라비올리를 추천합니다. #Person1#은 감자를 곁들인 양고기와 와인을 주문하고, Madame Culot은 평소 먹던 음식을 먹습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9035
# topic: 호텔 체크아웃 및 결제
# [DIALOGUE]
#  #Person1#: 저기요, 오늘 체크아웃할 예정인데 지금 계산하고 싶어요.
# #Person2#: 네, 참고로 체크아웃 시간은 12시입니다.
# #Person1#: 알겠습니다.
# #Person2#: Green 씨, 오늘 아침에 호텔 서비스를 이용하시거나 식당에서 아침 식사를 하셨나요?
# #Person1#: 네, 친구랑 식당에서 아침 식사를 했어요. 그런데 다른 서비스는 이용하지 않았어요.
# #Person2#: 그럼 친구분과 함께 묵으셨던 날들의 요금은 어떻게 처리할까요?
# #Person1#: 제 계정에 추가해주세요.
# #Person2#: 8일간 총 요금은 560위안입니다.
# #Person1#: 네, 여기 있습니다.
#
# [SUMMARY]
#  #Person1#은 체크아웃하기 위해 계산을 요청하였다. #Person2#는 #Person1#에게 호텔 서비스 사용 및 식사 여부를 확인하고, 모든 요금을 #Person1#의 계정에 추가하였다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4807
# topic: 사과 선호도
# [DIALOGUE]
#  #Person1#: 너 샌드위치랑 같이 뭐 먹을 거야?
# #Person2#: 과일 좀 먹을까 생각 중이야.
# #Person1#: 아 그래? 어떤 과일 좋아해?
# #Person2#: 포도랑 사과만 주로 먹어.
# #Person1#: 어떤 사과 좋아해?
# #Person2#: 난 항상 초록 사과를 좋아했어.
# #Person1#: 난 초록 사과 별로 안 좋아해.
# #Person2#: 그건 왜?
# #Person1#: 너무 신 것 같아서.
# #Person2#: 너는 빨간 사과가 더 좋나 보네?
# #Person1#: 맞아. 넌 빨간 사과 안 좋아해?
# #Person2#: 그냥 그런대로 괜찮아.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 샌드위치와 함께 먹을 과일에 대해 이야기합니다. #Person2#는 초록 사과를 좋아하고, #Person1#는 빨간 사과를 더 선호합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7770
# topic: 관리직 변화 논의
# [DIALOGUE]
#  #Person1#: 요즘 경영진이 많이 바뀌고 있어. Bill이 은퇴하고 부서 재편성까지 하면서, 관리자 인원의 1/3 정도를 잃은 상태야. 정말 빠르게 줄어들고 있어...
# #Person2#: 그게 좋은 거 아니야? 상사가 줄어들면 스트레스가 줄어들지 않겠어?
# #Person1#: 사실은 그렇지 않다고 생각해. 직장에서 모든 게 순조롭게 진행되려면 감독자가 정말 중요하다고 생각해. 그들은 일을 나누고 직원들을 관리하는 데 필요해. 감시하는 사람이 없으면 아무도 일을 안 하려고 할 거야. 그런 말 있잖아, 고양이가 없으면 쥐들이 놀아요.
# #Person2#: 맞아, 우리에게는 리더십이 필요해. 하지만 우리가 필요 없는 건 너무 많은 리더들이지. 그런 말도 있잖아, 수장은 많고 인디언이 부족하다고...
# #Person1#: 알겠어... 네 말도 이해해.
#
# [SUMMARY]
#  #Person1#은 관리직 직원의 1/3이 줄어든 상황에 대해 이야기하고, #Person2#는 이것이 긍정적일 수 있다고 언급한다. #Person1#은 감독자가 효율적인 업무를 위해 필요하다고 설명하지만, #Person2#는 과도한 감독은 불필요하다고 생각한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10158
# topic: 변덕스러운 날씨
# [DIALOGUE]
#  #Person1#: 오늘 날씨 참 좋지 않아?
# #Person2#: 네, 맞아요. 비 오고 나서 정말 좋네요.
# #Person1#: 다시 해가 나서 정말 좋다! 공기도 너무 상쾌하고.
# #Person2#: 이렇게 좋은 날씨가 오래 갔으면 좋겠어요.
# #Person1#: 이맘때 날씨는 워낙 변덕스럽잖아요.
# #Person2#: 맞아요. 내일 날씨가 어떨지 모르겠어요.
# #Person1#: 봐봐! 비 올 것처럼 보이는데.
# #Person2#: 오늘은 맑다고 하던데요.
# #Person1#: 날씨는 예보랑 다를 때가 많으니까요.
#
# [SUMMARY]
#  #Person1#과 #Person2#가 변덕스러운 날씨와 기상 예보와의 차이에 대해 이야기하고 있습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7671
# topic: 신발 구입
# [DIALOGUE]
#  #Person1#: 이런 신발 있나요?
# #Person2#: 사이즈가 어떻게 되세요?
# #Person1#: 다섯 사이즈요.
# #Person2#: 색상은 어떤 걸 찾으시나요?
# #Person1#: 검정색이요.
# #Person2#: 죄송하지만, 지금은 없어요.
# #Person1#: 제 동생이 지난달에 이거 샀다는데요.
# #Person2#: 여기서 사셨나요?
# #Person1#: 아니요, 미국에서 샀어요.
# #Person2#: 한 달 전까지는 그런 신발이 있었는데, 지금은 없어요.
# #Person1#: 저한테 한 켤레 구해줄 수 있나요?
# #Person2#: 그게 좀 어렵네요. 작년이나 재작년에 유행했지만, 올해는 유행이 아니거든요. 지금 유행하는 신발은 이거예요.
# #Person1#: 상당히 불편해 보이네요.
# #Person2#: 정말 불편해요. 하지만 여자들은 항상 불편한 신발을 신으니까요.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 올해는 유행하지 않아 #Person1#이 찾는 종류의 신발을 갖고 있지 않다고 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_724
# topic: TV 수리 요청
# [DIALOGUE]
#  #Person1#: 안녕하세요, 매니저님과 이야기할 수 있을까요?
# #Person2#: 무슨 일 있으신가요? 어떤 문제가 있나요?
# #Person1#: 어제 오후에 가게에서 TV를 샀는데, 차에서 내릴 때 실수로 떨어뜨렸어요. 겉으로는 괜찮아 보이는데 화면이 조금 흐리더라고요. 누가 좀 봐주거나 교환할 수 있을까요?
# #Person2#: 알겠습니다. 매니저님께 말씀드릴게요. 잠시만 기다려 주세요.
# #Person1#: 네, 감사합니다.
# #Person2#: 저희가 수리해 드릴 수는 있지만, 고객님 과실로 인한 것이기 때문에 수리비의 절반은 부담해주셔야 하고 나머지는 저희가 부담하겠습니다.
# #Person1#: 그렇게 해주시면 괜찮습니다. 감사합니다.
#
# [SUMMARY]
#  #Person2#는 #Person1#의 TV를 수리할 수 있으나, #Person1#의 과실로 인한 것이므로 수리비의 절반을 #Person1#이 부담해야 합니다. #Person1#은 이에 동의합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1614
# topic: 취업 면접
# [DIALOGUE]
#  #Person1#: 안녕하세요. 판매직 모집 광고 보고 왔어요.
# #Person2#: 알겠습니다. 이쪽으로 걸어오세요. 어떤 경력이 있으신가요?
# #Person1#: 이런 종류의 일에는 경험이 없어요. 대학에서 경영학을 공부하고 있는데, 관련된 일을 하고 싶거든요.
# #Person2#: 판매 경험은 조금이라도 있나요?
# #Person1#: 지난 여름방학에 작은 마을의 백화점에서 일했어요.
# #Person2#: 이제 학력에 대해 말씀해주세요.
# #Person1#: 베이징 대학교를 졸업했어요. 경영학을 전공했죠.
# #Person2#: 어떤 과목들을 이수했나요?
# #Person1#: 마케팅, 상법, 비즈니스 영어, 통계학, 마케팅 원론, 판매 관리, 유통 이론, 경제학, 심리학을 이수했어요.
# #Person2#: 대학에서 가장 좋아했던 과목은 무엇인가요?
# #Person1#: 판매 전략을 가장 좋아했어요.
# #Person2#: 왜 우리 회사에서 일하고 싶나요?
# #Person1#: 흥미로운 직업이고, 당신의 회사는 가장 잘 알려진 회사 중 하나입니다. 비록 판매직 경험은 없지만, 보내주신 직무 설명이 매우 흥미로웠어요. 대학 시절부터 꿈꿔오던 직업이라서요.
# #Person2#: 미래 계획은 무엇이고, 회사에 대해 어떤 기대를 가지고 있나요?
# #Person1#: 마케팅에 관심이 있고, 앞으로 경영학 대학원을 고려할지도 몰라요. 경험을 쌓으면서 목표가 더욱 명확해질 것 같아요.
# #Person2#: 좋습니다. 저희 회사에 대해 아는 것이 있나요?
# #Person1#: 네, 조금요. 방금 말씀하신 것처럼, 귀사는 미국 자본 기업이죠. 제가 아는 한 화장품 및 스킨케어 제품을 생산하는 세계적으로 유명한 회사입니다.
# #Person2#: 저에게 질문하고 싶은 게 있나요?
# #Person1#: 이 직책에서 여행을 자주 가야 하나요?
# #Person2#: 네.
# #Person1#: 얼마나 자주인가요?
# #Person2#: 최대 연 3회 정도입니다. 괜찮으신가요?
# #Perso
#
# [SUMMARY]
#  #Person1#이 판매직 모집 광고를 보고 #Person2#와 면접을 진행합니다. #Person2#는 #Person1#에게 업무 경험, 학력, 이수한 과목, 좋아하는 과목, 회사에서 일하고 싶은 이유, 미래 계획과 기대에 대해 묻습니다. #Person1#은 출장 빈도에 대해 질문합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7559
# topic: 운동 방법 추천
# [DIALOGUE]
#  #Person1#: 이제 웨이트 머신을 한번 써볼까?
# #Person2#: 로잉 머신은 어때?
# #Person1#: 좋아. 다들 TV가 내장되어 있네.
# #Person2#: 좋네! 앨리 맥빌 볼 수 있겠어!
# #Person1#: 그런데 우리 거기서 20분만 머물 건가?
# #Person2#: 엉덩이를 단단하게 만들려면 어떤 운동을 해야 할까?
# #Person1#: 나는 스쿼트를 추천해. 발은 어깨 너비로 벌리고, 발가락은 정면으로 향하게 하고 천천히 무릎을 굽혀봐.
# #Person2#: 이렇게?
# #Person1#: 허리를 곧게 펴고 정면을 보면서. 좋아. 20회씩 3세트 해봐.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 체력 단련 시설을 이용하고 있으며, #Person1#은 #Person2#에게 엉덩이를 탄탄하게 하기 위한 방법으로 스쿼트를 추천합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5993
# topic: 유행과 편견
# [DIALOGUE]
#  #Person1#: 너, Miss Foley 선생님 반의 새로운 학생 봤어? 걔 좀 사는 형편이 안 좋은 거 같아 보이지 않아?
# #Person2#: 사는 형편이 안 좋다고? 왜 그렇게 생각해?
# #Person1#: 청바지에 천 조각들이 붙어있던데. 틀림없이 청바지에 구멍이 나서 새 거 살 돈이 없었던 거겠지. 아마 엄마가 그 낡은 청바지를 고치려고 천을 붙였을 거야.
# #Person2#: Rusty, 너 좀 구식이구나. 그거 요즘 유행이야. 우리 반의 절반이 청바지에 천을 붙이고 다녀. 만약에 걔 부모님이 정말 힘든 상황이면 우리가 당연히 도와야지.
# #Person1#: 그러게, 맞아. 언제든 도움 필요한 사람들을 도와야지.
#
# [SUMMARY]
#  Rusty는 Miss Foley 선생님 반의 새 학생이 청바지에 붙은 천 조각 때문에 형편이 어려운 것 같다고 생각하지만, Sally는 그것이 유행이라고 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1355
# topic: 산행 중 피로
# [DIALOGUE]
#  #Person1#: 래리, 피곤해. 좀 쉬면 안 될까?
# #Person2#: 뭐? 피곤하다고? 근데 우리 방금 시작한 지 20분밖에 안 됐잖아.
# #Person1#: 알아, 근데 진짜 피곤해. 속도도 이상해.
# #Person2#: 왜 그래? 어젯밤에 잘 못 잤어?
# #Person1#: 어젯밤에 너무 설레서 잠을 잘 못 잤어. 꽤 늦게 잤어.
# #Person2#: 그럼 몇 시에 잤어?
# #Person1#: 새벽 2시쯤.
# #Person2#: 뭐라고?
# #Person1#: 새벽 2시쯤.
# #Person2#: 아, 수지야. 내가 충분히 자지 않으면 산을 못 오를 거라고 얼마나 말했어?
# #Person1#: 너 말이 맞아, 근데 어쩔 수가 없었어.
# #Person2#: 오늘 하루 일정이야. 정오까지 꼭 정상에 오르거나 지금 포기하고 집에 가야 해. 너는 뭐 할래?
# #Person1#: 뭐 할지? 포기하고 싶진 않은데 정말 피곤해.
# #Person2#: 그래서 빨리 결정을 내려. 계속 갈 건지 포기할 건지.
# #Person1#: 생각 좀 해볼게. 어쩌지? 포기하지 않을래.
#
# [SUMMARY]
#  래리와 수지는 산을 오르던 중, 수지가 잠을 못 자 피곤해한다. 래리는 계속 갈지 포기할지 물으며 수지는 결국 계속 가기로 결정한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5277
# topic: 방 교체
# [DIALOGUE]
#  #Person1#: 안녕하세요, 손님. 무엇을 도와드릴까요?
# #Person2#: 저는 Bill이에요. 908호에 머물고 있습니다. 방을 좀 바꿀 수 있을까요? 너무 시끄러워요. 제 아내가 화물 엘리베이터 소리 때문에 여러 번 깼거든요. 많이 힘들어했어요.
# #Person1#: 정말 죄송합니다, 손님. 사과드립니다. 908호가 복도 끝에 있어서 소음이 들릴 수 있습니다.
# #Person2#: 어쨌든 방을 바꾸고 싶습니다.
# #Person1#: 알겠습니다, 손님. 그렇게 하겠습니다. 하지만 오늘은 빈 방이 없습니다. 내일까지 기다려주실 수 있을까요? 내일 아침 미국인 교육 대표단이 떠나면 선택할 수 있는 방이 나올 겁니다.
# #Person2#: 알겠습니다. 내일 저녁에 조용한 스위트룸에서 편안히 잘 수 있기를 바랍니다.
# #Person1#: 물론입니다. 메모해 두겠습니다. 모든 것이 잘 처리될 것입니다. 필요하신 것이 더 있으면 언제든 말씀해 주세요.
#
# [SUMMARY]
#  Bill은 방이 시끄러워서 방을 바꾸고 싶어 합니다. #Person1#은 소음에 대해 사과하고 내일 Bill의 방을 바꿔주기로 약속합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10791
# topic: 새로운 만남과 친구 관계
# [DIALOGUE]
#  #Person1#: 헤이, Mary. 잘 지내?
# #Person2#: 별일 없어. 어젯밤 바에서 멋진 남자를 만났어. 정말 즐거운 시간을 보냈고, 오늘 밤에 다시 만나기로 했어.
# #Person1#: 와, 정말 신나는 소식이네. 그 남자 어때? 잘생겼어?
# #Person2#: 처음엔 잘 모르겠더라. 그런데 얘기를 나누다 보니 엄청 유머러스하고 재치 있더라구. 그의 농담에 웃음이 멈추질 않았어! 공통점도 많고. 우리가 좋아하는 팀이나 음악도 같아.
# #Person1#: 너희 둘 정말 잘 어울리는 것 같아. 친구로서 어떤 점을 중요하게 생각해?
# #Person2#: 꼭 정해진 건 없어. 목록 같은 건 없지만, 처음 만났을 때 그 사람과 친구가 될 수 있을지 보통 감으로 알 수 있어. 어쩌면 내가 무슨 감지기라도 있는 것 같아.
# #Person1#: 그런 이야기 처음 들어보네. 근데 내가 친구에게 가장 중요하게 생각하는 건 정직함이야.
# #Person2#: 맞아. 정직하지 않은 사람과 가까운 관계를 기대할 수 없어. 그런 사람들은 필요할 때 외면하거든.
# #Person1#: 그렇지, 나도 알아. 필요할 때 도와주는 친구가 진정한 친구지. 변덕스러운 친구는 필요 없어.
#
# [SUMMARY]
#  Mary는 #Person1#에게 어젯밤 바에서 유머러스하고 재치 있는 남자를 만났다고 말한다. 그들은 오늘 밤 다시 만나기로 했다. #Person1#과 Mary는 둘 다 친구에게 정직함이 중요하다고 동의한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1732
# topic: 바이러스 감염
# [DIALOGUE]
#  #Person1#: 어디 아파? 얼굴이 창백해 보여.
# #Person2#: 잘 모르겠는데, 몸이 좀 춥다가도 덥고 그래.
# #Person1#: 언제부터 그랬어?
# #Person2#: 밤새 거의 아팠어.
# #Person1#: 독감에 걸린 것 같은데. 체온 재볼게.
# #Person2#: 열이 많이 나?
# #Person1#: 응, 38.7도야. 두통이나 가슴, 목구멍 아파?
# #Person2#: 응, 그래.
# #Person1#: 이제 좀 살펴볼게. 가슴 소리 한번 들어보자. 깊게 숨 쉬고, 그렇게. 기침해봐, 이제 한 번 더. 목구멍도 좀 볼게. 크게 벌리고, '아아-' 해봐.
# #Person2#: 아아아, 아아아.
# #Person1#: 그래, 좀 부은 것처럼 보여. 흉부 엑스레이 찍고 몇 가지 검사 해보자.
# #Person2#: 알겠어, 고마워.
# #Person1#: 검사 결과 문제는 없었어. 약한 바이러스 감염이야.
# #Person2#: 오늘 뭘 해야 할까?
# #Person1#: 항생제랑 아스피린 줄게. 열이 나면 아스피린 먹고, 네 시간마다 항생제 캡슐 하나씩 먹어. 이틀 간은 집에서 푹 쉬고 물 많이 마셔. 그러면 나아질 거야. 여기 처방전이야.
#
# [SUMMARY]
#  #Person1#이 #Person2#의 체온을 측정하고 가슴과 목을 검사한 결과, #Person2#가 가벼운 바이러스 감염에 걸렸다는 것을 확인합니다. #Person1#은 #Person2#에게 항생제와 아스피린을 처방하고 휴식을 권장합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_11478
# topic: 방 청소 요청
# [DIALOGUE]
#  #Person1#: 안녕하세요, 선생님. 불편을 드려 죄송합니다. 지금 방 정리해도 될까요?
# #Person2#: 네, 부탁드려요. 우리는 지금 나가는 길이에요. 방 청소 중 표시를 걸어주시겠어요? 그리고 수건이랑 옷걸이 좀 가져다 주시겠어요?
# #Person1#: 네, 문제 없습니다, 선생님. 돌아오시면 모든 게 준비되어 있을 거예요.
#
# [SUMMARY]
#  #Person2#가 #Person1#에게 방 정리를 허락하고 추가 요청을 합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8752
# topic: 해변 나들이
# [DIALOGUE]
#  #Person1#: 일어나, 잠꾸러기. 해가 뜰 시간이야. 오늘 정말 멋진 여름날이야!
# #Person2#: 맞아, 하늘이 정말 맑네. 하지만 난 좀 더운 것 같아. 더위랑 습도는 별로야.
# #Person1#: 그렇게 덥진 않아. 어제보다 시원한데. 수영하러 가자!
# #Person2#: 괜찮은 생각이야. 아직 이른 시간이니까 해변에 사람이 많지 않겠지. 너무 오래 있지 않으면 햇볕에도 안 탈 거야.
# #Person1#: 그래, 재미있겠어. 새로 산 분홍색 비키니를 입어야지.
# #Person2#: 네가 귀엽다는 걸 알아줄 사람들은 없을 걸.
# #Person1#: 신경 안 써! 현명한 남자들은 일찍 오잖아. 그런 남자를 만나고 싶어. 가자!
# #Person2#: 네가 비키니 입고 남자들을 만나러 간다면, 나도 하나 입고 싶어.
# #Person1#: 좋아, 내 것 중 하나 빌려줄게.
# #Person2#: 고마워, 초록색이랑 검은색 줄무늬 그거 어때?
# #Person1#: 좋아, 여기 있어.
#
# [SUMMARY]
#  #Person1#은 수영하러 가자고 제안하며 자신이 새로 산 비키니를 입을 것이라 말하고, #Person2#는 동의하면서 #Person1#의 초록색과 검은색 줄무늬 비키니를 빌린다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4773
# topic: 주문 및 배송 협의
# [DIALOGUE]
#  #Person1#: 이 문제를 해결하려면, Mr. Smith, 주문량을 절반으로 줄이는 걸 추천드립니다. 나중에 추가 주문을 하실 수 있습니다.
# #Person2#: 음, 그 가능성도 고려해보겠습니다. 그런데, 6월에 물건을 받으려면 언제까지 L/C를 개설해야 하나요?
# #Person1#: 원하는 배송 시점의 한 달 전까지 하셔야 합니다.
# #Person2#: 배송을 좀 더 빨리 해주실 수 있나요?
# #Person1#: 물건 준비하고 서류 작성하고 선적 공간 예약하는 데 시간이 걸립니다. 한 달 미만으로 배송을 기대하기는 어렵습니다.
# #Person2#: 알겠습니다, Mr. Zhang. 주문량을 줄이지 않겠습니다. 귀사가 제안한 전체 수량을 받겠습니다. 집에 도착하자마자 귀사를 위해 L/C를 개설하겠습니다.
# #Person1#: 언제쯤 가능하신가요?
# #Person2#: 다음 달 초에요. 그동안 모든 준비 부탁드립니다. 제가 L/C를 보내드리면 물건이 신속히 발송되었으면 합니다.
# #Person1#: 안심하셔도 됩니다.
#
# [SUMMARY]
#  Mr. Zhang은 Mr. Smith에게 주문량을 줄일 것을 권유하며, 배송 전에 L/C를 개설해야 한다고 설명합니다. 그러나 Mr. Smith는 주문량을 줄이지 않고 집에 도착하자마자 L/C를 개설하겠다고 합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9770
# topic: 학부모 모임에 대한 걱정
# [DIALOGUE]
#  #Person1#: 안녕, Li Ming. 무슨 일 있어 보여. 무슨 일이야?
# #Person2#: 이번 주 토요일에 우리 반에서 학부모 모임이 있는데, 좀 걱정이 돼.
# #Person1#: 왜? 그날 일찍 나오면 되잖아.
# #Person2#: 지난번 시험을 잘 못 봤거든. 아빠가 알면 혼날까 봐.
# #Person1#: 믿을 수 없어. 우리 부모님은 나를 거의 혼내시지 않아.
# #Person2#: 너도 알잖아, 우리 아빠는 성격이 급해.
# #Person1#: 선생님께 도움을 요청해보는 건 어때?
# #Person2#: 좋은 생각이야.
#
# [SUMMARY]
#  Li Ming은 학부모 모임에 대해 걱정하고 있으며, #Person1#은 선생님께 도움을 요청하라고 제안한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7007
# topic: 호텔 예약 및 시설 안내
# [DIALOGUE]
#  #Person1#: 안녕하세요. 지금 방 있나요?
# #Person2#: 네, 있습니다. 몇 박 머무르실 건가요?
# #Person1#: 4박 가능한가요?
# #Person2#: 네, 확인해보겠습니다. 죄송합니다, 손님. 2박만 가능합니다. 지금은 아주 바쁜 시기라 거의 예약이 가득 찼습니다.
# #Person1#: 알겠습니다. 그러면 오늘 밤만 묵을게요. 지금 다른 호텔을 찾기엔 너무 늦었네요. 내일은 다른 데를 찾아볼게요.
# #Person2#: 훌륭한 선택입니다, 손님. 이해해주셔서 감사합니다. 그러면 1박에 싱글룸입니다. 여기 키 카드고 방은 7층에 있습니다.
# #Person1#: 감사합니다. 그런데 호텔에 수영장 있나요?
# #Person2#: 네, 15층에 있습니다. 하지만 오후 10시에 문을 닫아서 지금은 벌써 45분 전에 닫았습니다.
# #Person1#: 아쉽네요.
# #Person2#: 하지만 우리 호텔에는 24시간 운영하는 헬스장이 있습니다. 14층에 있어요.
# #Person1#: 좋네요, 알려주셔서 감사합니다.
# #Person2#: 천만에요, 손님. 아, 깜빡할 뻔했네요. 아침 식사는 2층에서 오전 6시 30분부터 10시까지 제공됩니다.
#
# [SUMMARY]
#  #Person1#이 4박을 원했지만 #Person2#가 2박만 가능하다고 해서 #Person1#은 오늘 밤만 머물기로 결정했습니다. #Person1#은 수영장이 닫혔지만 24시간 운영되는 헬스장을 이용할 수 있다는 정보를 받았습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_311
# topic: 지갑 분실
# [DIALOGUE]
#  #Person1#: 안녕하세요. 방금 거리에서 쇼핑하다 지갑을 잃어버렸어요. 누가 훔쳐간 것 같아요.
# #Person2#: 안타깝네요. 지갑에 어떤 것들이 들어 있었는지 말씀해 주시겠어요?
# #Person1#: 핸드폰이랑 여권, 현금이 좀 있었어요.
# #Person2#: 언제 미국에 오셨나요?
# #Person1#: 며칠 전에요.
# #Person2#: 지갑을 언제 어디서 잃어버렸는지 기억나세요?
# #Person1#: 전혀 모르겠어요.
# #Person2#: 네, 기록해뒀습니다. 미국에서의 비상 연락처는 누구인가요?
# #Person1#: 가까이에 사는 제 친구 Tim이에요.
# #Person2#: 알겠습니다. 단서가 발견되면 바로 연락드리겠습니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#에게 거리에서 쇼핑 중 지갑을 잃어버렸다고 보고합니다. #Person2#는 단서가 발견되면 연락하기 위해 #Person1#의 비상 연락처를 요청합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10084
# topic: 아파트 임대
# [DIALOGUE]
#  #Person1#: 안녕하세요.
# #Person2#: 네, 안녕하세요. 오늘 신문에서 본 아파트 광고 때문에 전화드렸어요.
# #Person1#: 네, 알겠습니다.
# #Person2#: 제가 좀 급해서요. 빨리 구해야 해요.
# #Person1#: 네, 어떤 걸 알고 싶으세요?
# #Person2#: 일단, 크기는 어떻게 되나요?
# #Person1#: 두 개의 침실이 있는 아파트이고, 거실, 식당, 부엌, 그리고 욕실이 하나 있어요. 세탁기와 건조기를 놓을 공간도 있습니다.
# #Person2#: 아, 그럼 아파트 단지는 얼마나 오래됐나요?
# #Person1#: 음, 역사가 있다고 할 수 있죠. 솔직히 말해서 1920년대에 저희 증조부가 지으셨지만, 건물이 아주 견고하고 튼튼해요.
# #Person2#: 아, 그리고... 그럼, 가구는 얼마나 갖춰져 있나요?
# #Person1#: 아, 네. 아파트에는 냉장고, 가스레인지와 할머니의 오래된 식기 세척기가 부분적으로 갖춰져 있어요.
# #Person2#: 할머니의 오래된 식기 세척기요? 알겠어요. 월세는 얼마인가요?
# #Person1#: 월 950달러예요.
# #Person2#: 와, 그건 제게 조금 비싸네요.
# #Person1#: 방을 만약에 방 친구와 같이 쓰시면 비용을 나눌 수 있을 거예요.
# #Person2#: 아마도요. 그럼 공과금은 포함인가요?
# #Person1#: 월세에는 가스와 전기는 포함이고, 전화 요금은 별도예요. 그리고 물 펌프는 바로 뒤쪽 문밖에 있어요.
# #Person2#: 물 펌프요!
# #Person1#: 네.
# #Person2#: 아, 네. 그럼 월 세입이 가능한가요, 아니면 장기로 계약해야 하나요?
# #Person1#: 저희는 6개월간의 약정을 요구하고, 그 기간 중에 계약을 취소하시면 보증금을 반환받지 못합니다.
# #Person2#: 아, 보증금은 얼마인가요?
# #Person1#: 400달러예요. 그리고 물론 이 돈은 아파트의 손상이나 마모를 수리하는 데 사용됩니다. 작년에 눈폭풍 때문에 지붕이 샜던 것도 그에 해당해요. 정말 안 좋았
#
# [SUMMARY]
#  #Person1#은 오늘 신문에서 본 아파트 광고에 관해 문의하기 위해 Norman Bates에게 전화합니다. Norman은 #Person1#에게 아파트의 크기와 방 구성에 대해 설명합니다. 아파트는 역사적으로 오래된 건물이지만, 부분적으로 가구가 갖춰져 있습니다. 월세는 950달러이며, #Person1#은 이를 비싸다고 생각합니다. Norman은 룸메이트와 함께 비용을 나누는 방안을 제안하면서, 포함된 항목을 설명합니다. Norman은 아파트에 대해 6개월 약정을 요구하고, 보증금 반환 정책에 대해 설명합니다. 또한, 아파트의 대학과의 거리, 주위 환경, 세입자 주차 공간, 위치 등에 관한 정보도 제공합니다. Norman은 작은 애완동물을 키우는 것을 허용합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2270
# topic: 인터넷 보안 문제
# [DIALOGUE]
#  #Person1#: 누가 당한 거야?
# #Person2#: 어떤 사람이 크게 당했대. 해커가 회사 파일에 침입해서 그 사람 개인 정보를 다 가져갔어. 완전히 안전하다고 생각해?
# #Person1#: 음, 100% 안전하다고는 못하겠네. 사람들이 몇 가지 방법을 사용한다고 들었어.
# #Person2#: 이제야 진실에 좀 더 가까워졌네.
# #Person1#: 쉘이라는 게 있어. 자기 물건의 가격을 올리려고 입찰하는 사람이야.
# #Person2#: 맞아, 온라인에서는 그런 게 쉽겠지. 모두가 익명이니까.
#
# [SUMMARY]
#  #Person2#는 해커가 한 사람을 속였다고 #Person1#에게 이야기하며, 두 사람 모두 인터넷이 완전히 안전하지 않다고 생각합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2861
# topic: 비즈니스 협상
# [DIALOGUE]
#  #Person1#: 조속한 회신을 부탁드리며, 상호 협력을 통해 빠르게 이 거래를 마무리할 수 있기를 바랍니다.
# #Person2#: 감사합니다. 가능한 빨리 답변 드리겠습니다.
# #Person1#: 저희가 정말 최선을 다하고 있다는 점을 알아주셨으면 합니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#의 빠른 회신과 협력을 기대하고 있습니다. #Person2#는 곧 답변하겠다고 약속합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2054
# topic: 환승 항공기 탑승
# [DIALOGUE]
#  #Person1#: 우리 환승 항공편이 몇 시야?
# #Person2#: 잠깐만, 확인해볼게. 아, 3시 25분이야.
# #Person1#: 와, 시간 맞춰야겠네! 그럼 연결편까지 25분밖에 없네! 몇 번 게이트야?
# #Person2#: 14번 게이트야.
# #Person1#: 아, 맙소사! 터미널 끝쪽에 있잖아!
# #Person2#: 좋아, 착륙하면 바로 14번 게이트로 뛰는 거야!
# #Person1#: 바로 따라갈게!
#
# [SUMMARY]
#  #Person1#와 #Person2#는 환승 항공편을 타기 위해 급히 움직이고 있다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3107
# topic: 스웨덴의 날씨
# [DIALOGUE]
#  #Person1#: 내가 스웨덴에 산다고 하면 사람들이 항상 계절에 대해 궁금해해.
# #Person2#: 계절이?
# #Person1#: 응, 겨울에 얼마나 추운지 알겠지? 낮이 짧을 때는 어떤지?
# #Person2#: 그래서 실제로 어때?
# #Person1#: 글쎄, 겨울엔 진짜 추워. 가끔은 기온이 영하 26도까지 내려가. 밖에 나갈 땐 따뜻하게 챙겨 입어야 해. 근데 집 안은 항상 아주 따뜻해, 우리 집보다 더 따뜻하지. 스웨덴 사람들이 영국에 가면 겨울에도 집 안이 춥다고 하소연하곤 해.
# #Person2#: 어둠은 어때?
# #Person1#: 음, 맞아, 크리스마스 시기엔 낮 시간이 한 시간밖에 안 돼, 그래서 봄이 정말 기다려져. 때때로 조금 우울하기도 해. 하지만 여름은 정말 환상적이지, 5월에서 7월까지는 스웨덴 북쪽에선 해가 지지 않아. 자정에도 밝아. 산에 가서는 신문도 읽어볼 수 있어.
# #Person2#: 아, 그래, 백야의 나라구나.
# #Person1#: 응, 맞아, 정말 멋져. 밤새 깨어 있진 않지만. 스웨덴 사람들은 여름을 최대한 즐기지. 종종 여름에 일찍 일을 시작해서 오후 2시나 3시쯤 퇴근해 긴 여름 저녁을 즐길 수 있어. 일도 열심히 하지만 놀기도 좋아하지. 런던 사람들은 더 오래 일하긴 해, 그게 좋은 일인진 잘 모르겠어.
#
# [SUMMARY]
#  #Person1#은 #Person2#에게 스웨덴의 날씨를 소개하며, 겨울의 추위와 계절별로 변화하는 낮의 길이에 대해 이야기합니다. 스웨덴 사람들은 여름 저녁을 즐기기 위해 아침에 일찍 출근하고 오후 2시나 3시에 퇴근합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3894
# topic: 세관 짐 검사
# [DIALOGUE]
#  #Person1#: 안녕하세요, 여권 좀 주시겠어요?
# #Person2#: 여기 있습니다.
# #Person1#: 아, 감사합니다. 짐을 여기로 가져오셔서 검사받으세요.
# #Person2#: 알겠습니다. 그런데 문제가 있나요?
# #Person1#: 그냥 정기 검문입니다. 신고할 물건이 있나요?
# #Person2#: 담배 6갑과 샴페인 2병이 있어요. 그 외에는 개인용 카메라 하나와 선물용 카메라 하나가 있습니다.
# #Person1#: 음, 담배와 샴페인은 면세 한도 내입니다. 하지만 법에 따르면, 손님 한 분당 카메라 한 대만 면세가 가능합니다. 나머지 하나는 세금을 내셔야 해요.
# #Person2#: 알겠습니다. 세금은 어디서 내면 되나요?
# #Person1#: 잠시만 기다려 주세요. 제가 세금 메모를 작성해드릴게요... 여기 있습니다. 저기 있는 여자분께 가서 이걸 보여드리고 지불하세요.
# #Person2#: 지불했어요. 여기 영수증입니다.
# #Person1#: 잘하셨습니다. 미국에서 좋은 시간 보내세요.
# #Person2#: 감사합니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#의 짐을 정기적으로 검사하며, 면세 한도를 초과한 카메라에 대해 세금을 납부하라고 안내합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6735
# topic: 통금 시간
# [DIALOGUE]
#  #Person1#: 통금 시간을 좀 조정해보자.
# #Person2#: 좋아요. 다른 애들 부모님은 새벽 두세 시까지 놀게 하더라고요.
# #Person1#: 음, 난 다른 애들 아버지가 아니잖니. 넌 열 시까지는 집에 들어와야 한다고 생각해.
# #Person2#: 그건 너무해요.
# #Person1#: 네 친구들 대부분은 열 시 전에 집에 들어갈걸?
# #Person2#: 중학생 몇 명도 그 시간보다 늦게까지 나가 있어요.
# #Person1#: 네가 그렇게 늦게까지 나가 있으면 걱정돼.
# #Person2#: 좋아요, 그럼 자정으로 통금을 맞출까요? 그리고 제가 어디 있는지 알려드릴게요.
# #Person1#: 좋아, 근데 전화하면 꼭 받아야 돼.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 통금 시간에 대해 논의하고 있다. #Person1#은 자정 통금을 허락하지만, #Person2#에게 전화가 오면 꼭 받으라고 요청한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9482
# topic: 수업과 국적 다양성
# [DIALOGUE]
#  #Person1#: 안녕! 첫 수업 어땠어? 나는 레벨 2에 있는데 이번 학기 수업이 너무 좋아! 다양한 나라에서 온 친구들이랑 수업하는 게 정말 좋거든!
# #Person2#: 내 수업도 괜찮았어. 그런데 우리 반에는 영어 하는 사람이 전혀 없어. 그래서 아마 중국어로 대화해야 하는 상황이 많아서 이번 학기에는 정말 많이 늘 것 같아.
# #Person1#: 그게 좋기도 하고 좀 아쉽기도 하네. 내 반은 유엔 같은 곳이야! 세계 각지에서 온 사람들이 있어! 독일인 세 명, 폴란드인, 스코틀랜드인, 프랑스인 두 명, 미국인, 브라질인, 칠레인, 뉴질랜드인은 '키위'라고 부르길 좋아하는데, 그 사람도 있어. 또 모로코인, 토고인, 파키스탄인, 인도네시아인 두 명도 있고!
# #Person2#: 정말 다양한 국적의 사람들이네. 우리 반은 나 빼고 다 아시아 사람이야. 한국인 몇 명, 일본인 몇 명, 말레이시아인, 태국인, 싱가포르인, 필리핀인, 카자흐스탄 사람, 그리고 러시아인 한 명 있어.
# #Person1#: 나는 그게 꽤 운 좋다고 생각해. 아시아 문화를 정말 많이 배울 수 있는 기회잖아.
# #Person2#: 그렇긴 한데 반 친구들이랑 공감대가 없어서 힘들 것 같아, 특히 언어 장벽 때문에. 반을 옮길까 생각 중이야.
# #Person1#: 그러지 마! 그냥 계속 버텨봐! 말하는 중국어가 좋아질 거야. 연습 많이 해서 내 실력도 쉽게 넘길 걸.
# #Person2#: 그럴 리 없지. 네 여자친구는 중국인이잖아.
# #Person1#: 뭐, 그렇긴 하지.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 서로 자신의 반에 대해 이야기한다. #Person1#의 반은 다양한 국적의 학생들로 가득 차 있다. 반면, #Person2#의 반 친구들은 대부분 아시아 출신이라 #Person1#은 #Person2#가 중국어 실력을 향상시키고 아시아 문화를 배울 수 있는 기회라고 생각한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_11164
# topic: 수하물 찾기
# [DIALOGUE]
#  #Person1#: 저기요, 여기 KL17편 수하물 찾는 곳 맞나요?
# #Person2#: 네, 도와드릴까요?
# #Person1#: 이게 제 수하물 태그예요. 제 짐 좀 찾아줄 수 있나요?
# #Person2#: 네, 여기 있습니다.
# #Person1#: 정말 감사합니다.
#
# [SUMMARY]
#  #Person2#가 #Person1#의 수하물 찾기를 도와줍니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5651
# topic: 빠른 계산대
# [DIALOGUE]
#  #Person1#: 죄송하지만, 여기는 15개 이하 물건을 계산하는 빠른 계산대입니다. 보니까 15개보다 더 있는 것 같은데요.
# #Person2#: 아, 좀 봐주세요! 16개밖에 안 돼요! 좀 봐주시면 안 돼요?
# #Person1#: 알겠습니다. 물건을 벨트에 올려놓고 장바구니를 밀어주세요. 종이봉투 드릴까요, 비닐봉투 드릴까요?
# #Person2#: 비닐봉투로 주세요. 쿠폰도 몇 장 있어요.
# #Person1#: 괜찮습니다, 주세요. 그런데, 선생님, 이 쿠폰은 어제 만료됐네요.
# #Person2#: 이런! 뭐, 오늘은 정말 안 되는 날인가 보네요. 그래도 감사해요.
# #Person1#: 클럽 카드 있으세요, 아니면 현금으로 하실 건가요?
# #Person2#: 네, 클럽 카드 갖고 있어요. 여기 있어요.
# #Person1#: 직불카드로 하실 건가요, 신용카드로 하실 건가요?
# #Person2#: 직불카드로요. 그리고 현금 인출도 가능할까요? 50달러면 좋겠어요.
# #Person1#: 네, 물론이죠. 총 금액은 78달러 33센트입니다. 여기가 영수증이에요. 좋은 하루 되세요.
#
# [SUMMARY]
#  #Person2#는 빠른 계산대에 물건을 한 개 더 가져왔고, #Person1#에게 규칙을 봐달라고 요청합니다. #Person2#는 쿠폰을 사용하려 했으나 #Person1#은 쿠폰이 어제 만료됐다고 합니다. #Person2#는 클럽 카드로 직불 결제를 한 후 현금을 인출합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_11233
# topic: 자금 도착 알림
# [DIALOGUE]
#  #Person1#: 좋은 아침입니다. Felix Wasserman 어소시에이츠의 Beth Jennings입니다.
# #Person2#: 안녕하세요, Lincoln 은행의 James Hong입니다.
# #Person1#: 안녕하세요, Mr. Hong. 무엇을 도와드릴까요?
# #Person2#: NX567822100007의 자금이 도착했다고 알려드리려고 전화했습니다.
# #Person1#: 정말 잘됐네요! 어제는 없어서 당분간 소식이 없을 줄 알았어요.
# #Person2#: 이제 도착했습니다. 계좌로 바로 입금해드릴까요?
# #Person1#: 그렇게 해 주시면 정말 감사하겠습니다.
#
# [SUMMARY]
#  James Hong은 Beth Jennings에게 NX567822100007의 자금이 도착했음을 알렸습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_429
# topic: 화성 탐사
# [DIALOGUE]
#  #Person1#: 로즈, 어젯밤에 TV 봤어?
# #Person2#: 응, 과학 프로그램 봤어. 꽤 재미있더라.
# #Person1#: 무슨 내용이었어?
# #Person2#: 화성이야. 과학자들이 거기에 물이 있을지도 모른대.
# #Person1#: 그렇다면, 언젠가 우리가 거기서 살 수도 있겠네.
# #Person2#: 그러면 좋겠어. 지난달에 미국이 화성에 두 개의 로봇 탐사선을 성공적으로 보냈다는 것 알아?
# #Person1#: 물론, TV에서 들었어. 2004년 1월 3일에 익스플로러 스피릿이 구세프 크레이터 근처에 착륙했어. 그리고 3주 후엔 스피릿의 쌍둥이 탐사선 오퍼튜니티가 메리디아니 플라눔에 착륙했지.
# #Person2#: 맞아. 둘 다 화성의 사진을 보내왔는데, 오퍼튜니티가 더 잘했다고 하더라.
#
# [SUMMARY]
#  로즈가 어젯밤에 본 과학 프로그램에 대해 이야기하며 화성의 물 존재 가능성과 미국의 화성 탐사선 성공 소식을 공유한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8149
# topic: 동물원 방문 회상
# [DIALOGUE]
#  #Person1#: Mikey, 이제 자러 갈 시간이야. 밖이 어두워졌잖아. 잠들기 전에 무슨 얘기하고 싶은 거 있어?
# #Person2#: 음, 동물원에 대해 얘기하고 싶어.
# #Person1#: 동물원? 아, 우리 동물원 갔을 때 정말 재미있었지. 동물원에서 뭐가 제일 좋았어?
# #Person2#: 음, 호저들이요.
# #Person1#: 호저들이 정말 크더라. 그리고 또 뭐가 기억나?
# #Person2#: 음, 기린 두 마리.
# #Person1#: 기린 두 마리? 걔들이 나보다 더 컸어, 아니면 작았어?
# #Person2#: 머리 위에 있었어.
# #Person1#: 내 머리 위에 있었다니, 정말 크더라. 그리고 더 기억나는 게 있어? 코끼리도 봤지 않았어?
# #Person2#: 응, 코끼리가 뭐했는지 기억나?
# #Person1#: 코끼리가 뭐 먹고 있었어?
# #Person2#: 응, 먹고 있었어. 우리한테 흙을 뿌리기도 했어.
# #Person1#: 정말? 어떻게 그렇게 했지? 발로?
# #Person2#: 아니, 코로.
# #Person1#: 그리고 너 오리도 먹이 줬었잖아. 오리 색깔은 뭐였어?
# #Person2#: 하얀색.
# #Person1#: 다른 동물들은 뭐가 기억나? 어떤 쇼 같은 거 있었지 않았어?
# #Person2#: 응, 새 쇼.
# #Person1#: 새들이 뭐 했어?
# #Person2#: 음, 날아다녔어. 한 마리가 특히 장난꾸러기였어.
# #Person1#: 그 새가 뭐 했어?
# #Person2#: 음, 남자가 하지 말라고 한 걸 했어.
# #Person1#: 아, 그렇구나. 그리고 나비도 봤지?
# #Person2#: 새 쇼 끝나고 나비를 봤어.
# #Person1#: 나비들이 어떤 곳에 있었어?
# #Person2#: 유리로 된 건물 안에 있었어.
# #Person1#: 유리 건물 안에 있었구나, 그래서 나비들이 밖으로 못 나간 거구나?
# #Person2#: 응, 공기가 내려와서 못 나갔어.
# #Person1#: 아, 그렇구나. 이제 자러 가야겠네.
#
# [SUMMARY]
#  Mikey와 #Person1#은 잠자기 전에 동물원에 대한 경험을 회상합니다. Mikey는 호저들, #Person1#의 머리 위에 있던 기린, 코로 흙을 뿌린 코끼리, 그들에게 먹이를 받던 흰 오리, 그리고 날아다니던 새 쇼를 기억합니다. 또한, 유리 건물 안에서 나비를 본 것도 떠올립니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5853
# topic: 은행 계좌 개설
# [DIALOGUE]
#  #Person1#: 예금 계좌를 개설하고 싶어요.
# #Person2#: 알겠습니다. 몇 가지 종류의 계좌가 있습니다.
# #Person1#: 이자율이 가장 높은 계좌로 하고 싶습니다.
# #Person2#: 그러면 Saver's Plus 계좌가 적합합니다.
# #Person1#: 4.5%라니 좋네요. 이 이자율을 받으려면 얼마나 유지해야 하나요?
# #Person2#: 계좌에 $10,000 이상을 유지해야 합니다. 그렇지 않으면 이자율이 3%로 떨어집니다.
# #Person1#: 알겠습니다. 그 계좌로 하나 개설할게요.
# #Person2#: 이 양식들을 작성해 주세요. 잠시 후 오겠습니다.
# #Person1#: 감사합니다.
#
# [SUMMARY]
#  #Person1#이(가) #Person2#의 안내로 이자율이 가장 높은 예금 계좌를 개설합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10271
# topic: 직장 생활
# [DIALOGUE]
#  #Person1#: 지원서 제출 결과는 어땠어?
# #Person2#: 응, 다음 주부터 일하러 오라고 연락 받았어.
# #Person1#: 어디서 일하게 된 거야?
# #Person2#: 꽤 큰 기계 회사인데, 조립 공장에서 일하게 됐어.
# #Person1#: 하루에 몇 시간이나 일해야 해?
# #Person2#: 근무 시간이 고정되어 있진 않아. 낮 근무도 있고 야근도 있는데, 대략 8시간 정도야.
# #Person1#: 꽤 힘들겠네.
# #Person2#: 그래도 내 전공이랑 맞아서 좋아.
# #Person1#: 월급은 어떻게 받아?
# #Person2#: 생산 결과에 따라서 월급이 달라져.
# #Person1#: 복지 시설은 괜찮아?
# #Person2#: 직원 전원에게 노동 보험이 제공되고, 퇴직금도 잘 되어 있어.
# #Person1#: 노조는 있어?
# #Person2#: 회사 노조가 있긴 한데 관리진하고 목표가 거의 같아.
# #Person1#: 그러면 일하기 전에 신중하게 생각해야겠다.
# #Person2#: 생각할게.
#
# [SUMMARY]
#  #Person1#이 #Person2#에게 새 직장에 대해 묻습니다. #Person2#는 근무 시간, 급여, 복지 시설, 회사 노조에 대해 설명합니다. #Person1#은 #Person2#에게 일을 시작하기 전에 신중하게 생각하라고 조언합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2420
# topic: 책 분실 사과
# [DIALOGUE]
#  #Person1#: 미안해, 네가 빌려준 책을 못 찾겠어.
# #Person2#: 괜찮아.
# #Person1#: 정말 미안해. 새 책 사줄게.
# #Person2#: 아니야. 그럴 필요 없어. 그러지 마.
#
# [SUMMARY]
#  #Person1#은 #Person2#가 빌려준 책을 찾지 못해 사과하며 새 책을 사주겠다고 제안하지만, #Person2#는 괜찮다고 응답합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6014
# topic: 학교 생활과 태도
# [DIALOGUE]
#  #Person1#: 좋은 소식 없어?
# #Person2#: 아니. 어제 생물 시간에 떠들다가 방과 후에 남아야 했어.
# #Person1#: 수업 중에는 조용히 있는 게 좋겠다.
# #Person2#: 가끔 그래. 그저께는 역사 시간에 조용히 있었는데도 방과 후에 남아야 했어.
# #Person1#: 이해가 안 돼.
# #Person2#: 수업 중에 잠들어서 그랬는데, 내 잘못이 아니라 수업이 너무 지루했어.
# #Person1#: 학교를 좀 더 진지하게 생각해봐. 시험 못 보면 자퇴하고 일해야 할지도 몰라.
# #Person2#: 별로 다를 것도 없을 것 같은데. 직장에 가면 매일 지루한 일 해야 하고, 학교에 있으면 매일 지루한 수업 들어야 하잖아.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 수업 중 말하다가 두 번 방과 후에 남게 되었고, 잠든 이유가 수업이 지루했기 때문이라고 설명합니다. #Person1#은 학교를 진지하게 받아들이라고 조언합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4959
# topic: 창문 열기 요청 및 감기
# [DIALOGUE]
#  #Person1#: 창문 좀 열어도 될까요?
# #Person2#: 미안한데, 그러지 말아 줬으면 해요. 제가 감기에 걸려서 추워요.
# #Person1#: 아, 안타깝네요. 의사를 불러 드릴까요?
# #Person2#: 그렇게 해주시면 좋겠어요.
# #Person1#: 알겠어요.
#
# [SUMMARY]
#  #Person1#이 창문을 열고 싶어 하지만 #Person2#이 감기에 걸려 있어 열지 못합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1513
# topic: 전화 시간 문의
# [DIALOGUE]
#  #Person1#: 마리 좀 바꿔주시겠어요?
# #Person2#: 마리는 지금 없어요. 엄마랑 쇼핑하러 갔거든요.
# #Person1#: 오늘 밤 10시쯤에 전화하면 너무 늦을까요?
# #Person2#: 괜찮아요. 우리는 일찍 자지 않거든요.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 오늘 밤 10시쯤 다시 전화해도 괜찮다고 말합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7670
# topic: 범죄 예방 조언
# [DIALOGUE]
#  #Person1#: 내일 밤 저녁 먹으러 우리 집에 올 거야?
# #Person2#: 물론이지. 아직 저녁 약속 있는 거 맞지?
# #Person1#: 응, 단지 너랑 네 룸메이트가 우리 집에 어떻게 올 계획인지 궁금해서.
# #Person2#: 지금 날씨도 좋고 해서 걸어올 계획이야.
# #Person1#: 그럴 줄 알았어. 있잖아, 내가 사는 동네가 좀 위험해. 바로 술집들 거리라서 밤에 걷는 건 별로 좋지 않을 거야.
# #Person2#: 그렇게까지 나쁠까?
# #Person1#: 안 그랬으면 좋겠지만, 범죄랑 매춘이 사실 이 근처에 많아.
# #Person2#: 진짜? 전혀 짐작 못 했어. 낮에 네 집에 있을 때 이상한 걸 본 적이 없어서, 아마 저녁에만 나오는 것 같아.
# #Person1#: 부탁인데, 택시 타고 와 줘. 그러면 걱정이 훨씬 덜할 것 같아.
# #Person2#: 알겠어, 그러지. 넌 저녁때 어떻게 다녀?
# #Person1#: 처음 이사 왔을 때는 걸어 다녔어. 그런데 일주일도 안 돼서 지갑을 도둑맞았어, 그것도 경찰서 바로 근처에서! 지금은 항상 대중교통 이용해.
# #Person2#: 또 다른 일은 없었어?
# #Person1#: 나한테 다른 일은 없었지만, 술집 다 문 닫을 때쯤이면 싸움이 종종 일어나더라.
# #Person2#: 응, 조심할게. 알려줘서 고마워.
#
# [SUMMARY]
#  #Person2#와 그의 룸메이트는 저녁 약속을 위해 #Person1#의 집에 걸어가려 했지만, #Person1#은 그 지역의 높은 범죄율을 설명하며 택시 이용을 권장합니다. #Person1#은 이사 초기 지갑을 도둑맞은 경험도 공유합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6755
# topic: 코트 구매
# [DIALOGUE]
#  #Person1#: Sarah, 오늘 뭐 했어?
# #Person2#: 쇼핑 갔었어.
# #Person1#: 뭐 샀어?
# #Person2#: 응, 몇 개 샀어.
# #Person1#: 뭐 샀는데?
# #Person2#: 이 코트 샀어. 어때, 마음에 들어?
# #Person1#: 응, 정말 예쁘다. 어디서 샀어?
# #Person2#: 5번가 쇼핑몰에서 샀어.
# #Person1#: 비쌌어?
# #Person2#: 아니, 안 비쌌어. 세일해서 20달러였어.
# #Person1#: 싸다.
# #Person2#: 맞아, 정말 좋은 거래였어.
# #Person1#: 근데 지금은 입을 필요 없을 것 같은데? 요새는 너무 덥잖아.
#
# [SUMMARY]
#  Sarah는 오늘 쇼핑을 갔다가 20달러에 코트를 구매했으며, #Person1#는 요즘 날씨가 더워 코트를 입을 필요가 없을 것 같다고 말했다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1358
# topic: 새로운 직장과 동료 소개
# [DIALOGUE]
#  #Person1#: 유니폼 멋지다!
# #Person2#: 고마워. 마음에 들어?
# #Person1#: 사실 별로야. 그냥 장난친 거야. 일 때문에 입는 거야?
# #Person2#: 응, 매장에서 일하는 사람들은 다 입어야 해. 우리를 더 프로페셔널하게 보이게 하려고 한다더라.
# #Person1#: 사실 그렇게 나쁘진 않네. 더 안 좋을 수도 있잖아. 너는 어떻게 생각해?
# #Person2#: 난 괜찮아. 매일 뭘 입을지 고민 안 해도 되니까.
# #Person1#: 새로운 일은 재미있어?
# #Person2#: 예전 일보다는 훨씬 나아. 새 상사도 좋아.
# #Person1#: 세일즈 일하는 건 어때?
# #Person2#: 사람들과 일하는 게 좋아. 그러면 시간이 더 빨리 가는 것 같아.
# #Person1#: 그거 좋네. Jane 만나봤어? 국제 여행부서 인턴이야.
# #Person2#: 응, 만났어. 정말 뛰어난 세일즈우먼이야!
# #Person1#: 맞아! 에스키모에게 냉장고도 팔 수 있을걸!
# #Person2#: 어떻게 알아?
# ...
#
# [SUMMARY]
#  #Person2#는 예치금을 갱신하기로 결정하고, #Person1#은 새로운 자동 갱신 서비스를 소개하여 #Person2#의 만족을 이끕니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4789
# topic: 사람 신뢰 여부
# [DIALOGUE]
#  #Person1#: 잭을 얼마나 오래 알았어?
# #Person2#: 우리 오래됐지. 아기 때부터 알았어.
# #Person1#: 진짜? 너희 정말 친하겠다.
# #Person2#: 응, 우린 아직도 죽마고우야.
# #Person1#: 걔 진지하고 믿음직스럽더라.
# #Person2#: 그래, 맞아. 근데 가끔 술수를 부릴 때도 있어.
# #Person1#: 무슨 뜻이야?
# #Person2#: 뭐, 나한테는 절대 배신하지 않아. 근데 다른 사람들한테는 이중적인 모습을 본 적 있어.
# #Person1#: 어머, 정말? 그런 사람일 줄은 몰랐어.
# #Person2#: 오해하지 마, 항상 그렇다는 건 아니야.
# #Person1#: 그럼 믿어도 되는 거야, 말아야 되는 거야?
# #Person2#: 음, 네가 스스로 결정하는 게 좋을 것 같아.
# #Person1#: 하지만 이 일에 믿을 만한 사람이 필요해.
# #Person2#: 알았어, 알았어. 믿어도 돼. 그냥 장난친 거였어.
# #Person1#: 진짜 헷갈리게 하네. 똑바로 말해줘.
# #Person2#: 사실 제일 믿을 만한 사람이고, 절대 아무도 배신하지 않아.
#
# [SUMMARY]
#  #Person1#은 Jack이 이 일에 신뢰할 만한 사람인지 #Person2#에게 묻습니다. #Person2#는 처음에 Jack에 대해 조심스러운 말을 하다가, 나중에 #Person1#이 Jack을 믿어도 된다고 확신을 줍니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5549
# topic: 논문 주제 선정
# [DIALOGUE]
#  #Person1#: 일어나, Erik, 아침이야.
# #Person2#: 어... 아, 안녕, Jane. 읽다가 잠들었나 봐.
# #Person1#: 너뿐만 아니라 다른 사람들도 그래. 여긴 도서관이 아니라 캠프장 같아.
# #Person2#: 기숙사는 너무 시끄러워서 공부하기 힘들고, 여긴 너무 조용해서 그런가 봐.
# #Person1#: 논문 주제는 좀 찾아봤어?
# #Person2#: 아니. Prof. Grant가 문화 인류학 관련 아무거나 쓰라고 했어. 가끔은 너무 선택지가 많아서 문제야.
# #Person1#: 그럼, 멕시코의 고대 문명에 대해 써보는 건 어때? 너 그쪽에 관심 많잖아.
# #Person2#: 나도 그래, 근데 자료가 너무 많아서 다루려면 끝도 없을 거야. Grant 교수님은 5~7페이지만 원하시잖아.
# #Person1#: 그러면 멕시코의 한 지역으로 한정해. 예를 들어 유카탄. 너 거기 가봤었고, 흥미로운 유물 많았다며.
# #Person2#: 나쁘지 않은 생각이야. 지난 여름에 책이랑 자료 많이 가져왔거든. 좋은 자료가 될 거야. 이제 그걸 어디 뒀는지 기억만 하면 되겠네.
#
# [SUMMARY]
#  Erik은 아직 논문 주제를 찾지 못했지만 Jane이 멕시코의 고대 문명을 제안하자 양이 너무 많다고 말합니다. Jane이 유카탄으로 범위를 좁히라고 조언하자, Erik은 동의합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7182
# topic: 지각
# [DIALOGUE]
#  #Person1#: 아침이야, Peter. 또 늦었네!
# #Person2#: 아, 진짜 미안해. 얼마나 미안한지 몰라.
# #Person1#: 이번엔 무슨 이유야?
# #Person2#: 알람을 꺼버리고 다시 잠들었어.
# #Person1#: 그래, 그리고 지난주에는 차가 고장 났었지.
# #Person2#: 응, 알아.
# #Person1#: 음...
# #Person2#: 정말 미안해. 다시는 안 그럴게.
#
# [SUMMARY]
#  Peter는 또다시 늦었습니다. 그는 미안해하며 다시는 늦지 않겠다고 약속합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8828
# topic: 직장 제안
# [DIALOGUE]
#  #Person1#: 헐! 거기 엄청 늦은 시간일 텐데. 몇 시야?
# #Person2#: 막 2시 넘었어.
# #Person1#: 무슨 일이야? 잠 못 자?
# #Person2#: 아니, 사실 너 기다리고 있었어. 너한테 할 말이 있어.
# #Person1#: 진짜? 뭔데?
# #Person2#: 오늘 네 도시에 있는 회사에서 일하라는 제안을 받았어.
# #Person1#: 믿을 수가 없어! 진짜야? 여기로 이사 오는 거야?
# #Person2#: 아직 수락한 건 아니고, 다가오는 휴일에 그 도시에 방문해서 회사도 직접 확인해보려고 해. 네가 시간이 된다면 직접 만나면 좋을 것 같아.
# #Person1#: 날짜만 알려줘. 내가 시간 비울게. 이렇게 온라인으로만 이야기하다가 실제로 만나는 날이 오다니 너무 좋을 것 같아. 빨리 만나고 싶어!
# #Person2#: 나도 그래. 하지만 이제는 자러 가야 할 것 같아. 머리가 무겁네. 거기서 좋은 하루 보내!
# #Person1#: 고마워. 정말 신난다. 잘 자고 좋은 꿈 꿔!
# #Person2#: 나중에 얘기하자.
#
# [SUMMARY]
#  #Person2#가 #Person1#에게 #Person1#의 도시에 있는 회사에서 일하라는 제안을 받았다고 말하고, 다가오는 휴일에 그 도시를 방문하여 회사를 직접 확인해보고 싶다고 한다. #Person1#은 그때 시간을 비워 #Person2#를 빨리 만나고 싶다고 한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2412
# topic: 영업 매니저 승진
# [DIALOGUE]
#  #Person1#: 안녕하세요, Cole. 무엇을 도와드릴까요?
# #Person2#: 몇 분 시간 괜찮으시면, 회사에서의 제 미래에 대해 이야기하고 싶어요.
# #Person1#: 물론이에요, 앉으세요.
# #Person2#: 감사합니다.
# #Person1#: 파일 좀 가져올게요. 여기서 얼마나 일하셨죠?
# #Person2#: 제가 이곳에서 영업 사원으로 일한 지 이제 1년 정도 됐어요.
# #Person1#: 벌써 1년이라니? 시간이 참 빠르네요. 일은 즐기고 계세요?
# #Person2#: 네, 그런데 승진 기회를 얻고 싶어요.
# #Person1#: 알겠어요. 어떤 일을 염두에 두고 있나요?
# #Person2#: 음, 영업 매니저 자리가 나는 걸 봤어요.
# #Person1#: 그 일이 어떤 의무를 수반하는지 알고 있나요?
# #Person2#: 네. 제 부서의 모든 영업 사원을 직접 책임져야 하고, 더 많은 회의나 서류 업무, 기타 책임들이 있을 거라고 생각해요.
# #Person1#: 맞아요. 관리 경력이 있나요?
# #Person2#: 네. 사실 제 이력서를 보시면, 이 일을 시작하기 전에 매니저로 일한 기록이 있어요.
# #Person1#: 그렇군요, 그 자리에 가장 적합한 후보라고 생각해요. 다만 회사 정책상 정식 지원 절차를 거쳐야 하니, 이 지원서를 작성해주세요.
# #Person2#: 알겠습니다. 지원해 주셔서 감사합니다.
#
# [SUMMARY]
#  Cole은 영업 사원으로 약 1년 동안 근무했으며, 영업 매니저로 승진을 희망합니다. #Person1#은 그가 적합한 후보라고 생각하고, 정식 지원 절차를 밟을 것을 안내합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10814
# topic: Mary의 이사 계획
# [DIALOGUE]
#  #Person1#: 안녕, Mary. 너희 정말 이사 간다는 게 사실이야?
# #Person2#: 아마도. 하지만 Jack에게 달려 있어. 그가 새 직장을 얻으면, 우리 Boswell로 이사해야 해.
# #Person1#: Highland Park가 그리울 거지, 그렇지?
# #Person2#: 물론이지. 하지만 Jack에게는 훨씬 더 큰 기회야. 급여도 더 많이 받을 수 있고, 아이들을 위한 좋은 학교도 있어. 다만, 그 동네가 Highland Park만큼 좋진 않을 것 같아.
# #Person1#: 일 그만두는 거야?
# #Person2#: 아마 교사로 일할까 해. Boswell에 새 고등학교가 생기는데, 거기서 교사를 구하고 있거든.
#
# [SUMMARY]
#  Mary는 Jack이 새 직장을 얻으면 Highland Park를 떠나 Boswell로 이사할 계획이라고 #Person1#에게 말한다. Mary는 Boswell에서 교사로 일할 예정으로, 새 고등학교에 지원할 계획이다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4498
# topic: CEO 역할 논의
# [DIALOGUE]
#  #Person1#: 쟤 자신이 대체 누군데 저렇게 굴지? 우리 상사가 요즘 사람들한테 명령하는 게 말도 안 돼. 자기가 CEO라도 된 줄 알겠어.
# #Person2#: 음... 너 메모 못 받았나 본데, 네 상사가 CEO 자리 공백을 채우게 됐어. 공식 발표 끝나면 정식 CEO가 될 거야.
# #Person1#: 헉, 진짜야? 믿기지 않아. 요즘 스트레스를 많이 받고 명령을 많이 하길래 왜 그러나 했어. 다른 부서에도 명령해서 그냥 잘난 척하는 줄 알았는데. 큰 자리였네!
# #Person2#: 맞아! 지난 CEO가 떠난 후에 우리 다 회사 미래 걱정 많이 했잖아.
# #Person1#: 근데 CEO가 대체 무슨 일을 하는 걸까? CEO가 제일 돈을 많이 번다는 건 알겠는데, 실제로 어떤 일을 하지?
# #Person2#: 회사에서 일어나는 모든 일에 대해 이사회에 책임을 져야 해. 회사의 모든 임원진에게 리더십을 제공하고 회사의 철학을 이끌어야 해. 또 공식적인 회사 대표로서의 역할도 맡아야 해.
# #Person1#: 진짜 똑똑한 사람이어야겠네.
#
# [SUMMARY]
#  #Person1#은 상사가 CEO처럼 행동한다고 불평하고, #Person2#는 상사가 실제로 CEO 자리를 맡게 된다고 설명한다. 그들은 또한 CEO의 역할에 대해 논의한다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9868
# topic: 기차 티켓 구매
# [DIALOGUE]
#  #Person1#: 안녕하세요, 브뤼셀까지 가는 편도 티켓을 사고 싶어요.
# #Person2#: 물론이죠. 여기 저희 기차 시간표입니다. 아침에 출발하는 급행열차와 밤 9시에 출발하는 야간열차가 있습니다.
# #Person1#: 거기까지 가는 데 얼마나 걸리나요?
# #Person2#: 약 12시간 정도 걸립니다. 현재 급행열차 1등석밖에 표가 남아 있지 않습니다. 원하시면 조금 더 저렴한 야간열차 침대로 선택하실 수 있습니다.
# #Person1#: 네, 그게 제일 좋은 선택인 것 같네요. 기차에서 음식을 제공하나요? 12시간은 꽤 긴 시간이네요!
# #Person2#: 네, 물론입니다. 기차 앞쪽에 식당차가 있어서 언제든지 식사를 할 수 있어요. 저희는 모든 승객에게 무료로 물과 커피를 제공합니다.
# #Person1#: 좋네요! 그걸로 할게요.
# #Person2#: 여기 있습니다. 손님. 기차는 9시 정각에 9번 플랫폼에서 출발합니다. 예정된 출발 시간 최소 30분 전에 여기 오셔야 기차를 놓치지 않으실 겁니다!
# #Person1#: 알겠습니다. 감사합니다!
# #Person2#: 즐거운 여행 되세요.
#
# [SUMMARY]
#  #Person1#은 브뤼셀로 가는 편도 티켓을 구매하려고 합니다. #Person2#는 #Person1#이 야간열차 침대칸을 선택하도록 돕고, 최소 30분 전에 도착할 것을 안내합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5601
# topic: Susan의 결혼 소식
# [DIALOGUE]
#  #Person1#: 너 Susan이 결혼했다는 거 믿어져?
# #Person2#: 진짜? 예전에 자기는 혼자 살겠다고 했던 거 기억나. 그 남자가 엄청 부자인가 봐?
# #Person1#: 아니. 그래서 더 놀라운 거야.
# #Person2#: 그러니까 부자인 사람과 결혼한 게 아니구나.
# #Person1#: 그는 그냥 우체부야.
# #Person2#: 난 그녀가 부자랑 결혼할 줄 알았는데.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 Susan이 우체부와 결혼한 것에 놀라고 있습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_8948
# topic: 산악 자전거와 올림픽
# [DIALOGUE]
#  #Person1#: 글쎄, 이제 운동 좀 쉬어가는 거야?
# #Person2#: 뭐, 체조는 안 돼도 산악 자전거는 탈 수 있잖아.
# #Person1#: 산악 자전거가 올림픽 종목이라고?
# #Person2#: 그렇지, 1996년부터였어. 나 꽤 잘 타. 거의 매일 자전거로 출퇴근하거든.
#
# [SUMMARY]
#  #Person2#는 #Person1#에게 산악 자전거가 1996년부터 올림픽 종목이었고 자신이 자전거를 잘 탄다고 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4412
# topic: 옷 세탁
# [DIALOGUE]
#  #Person1#: 좋아, 한 번만 더 살펴보자. 이제 더 이상 망가진 셔츠나 염색된 블라우스는 보고 싶지 않아!
# #Person2#: 알아, 알아. 그러니까 색깔 있는 옷과 하얀 옷을 따로 분리해서 이 이상하게 생긴 이른바 세탁기라는 곳에 넣으라는 거지.
# #Person1#: 맞아. 전원 켜고, 어떤 옷을 세탁하는지에 따라 설정하라고. 예를 들어 섬세한 옷은 세탁 시간을 짧게 설정해야 해. 그리고 빨래할 때 섬유 유연제랑 이 세제를 꼭 사용해.
# #Person2#: 너무 복잡해! 자, 이 빨간 와인 얼룩은 어쩌면 되지?
# #Person1#: 이건 흰 티셔츠니까 그냥 표백제를 조금 부으면 돼.
# #Person2#: 멋지네. 그럼 이걸 다 드라이어에 넣고 한 시간 돌리기만 하면 끝이지?
# #Person1#: 안 돼! 섬세한 옷과 면은 중간 온도로 20분만 설정해야 해.
# #Person2#: 있잖아, 그냥 다 드라이 클리닝 맡길게.
#
# [SUMMARY]
#  #Person1#이 #Person2#에게 세탁기를 사용하여 다양한 종류의 옷을 세탁하고 건조하는 방법을 설명합니다. #Person2#는 복잡하고 어렵다고 느낍니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_9355
# topic: 급여 인상 제안
# [DIALOGUE]
#  #Person1#: 올해 당신이 정말 훌륭하게 일해줘서 매우 만족하고 있어요.
# #Person2#: 제 일이 당신과 회사에 인정받아서 정말 기뻐요.
# #Person1#: 당신의 기여를 반영해 급여를 인상해드리고 싶어요. 월급이 800위안 올라갈 거예요. 이 인상은 성과와 늘어난 책임에 따른 80%와 생활비 변화에 따른 20% 증액을 반영했어요.
# #Person2#: 정말 감사합니다. 고맙습니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#의 훌륭한 성과로 급여 인상을 제안하며, #Person2#는 이에 감사의 뜻을 표합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_5066
# topic: 이력서 제출
# [DIALOGUE]
#  #Person1#: 여기 이력서 있습니다.
# #Person2#: 이름이 어떻게 되시죠?
# #Person1#: David, Chou입니다.
# #Person2#: 아, 네, Mr. Chou. 기다리고 있었습니다.
# #Person1#: 여기 요청하신 제 학력과 경력에 관한 모든 개인 서류들입니다. 중요한 회의가 있어서 지금 가봐야 해요. 만약 제가 적합하다면 알려주세요.
# #Person2#: 네, 명함 주시면 연락드리겠습니다.
# #Person1#: 죄송하지만, 지금 그건 없네요.
# #Person2#: 그러면 전화번호라도 알려주세요.
# #Person1#: #PhoneNumber#입니다.
#
# [SUMMARY]
#  David Chou씨는 #Person2#에게 학력과 경력 관련 서류를 제출하고, 전화번호를 제공합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7665
# topic: 컴퓨터 구매
# [DIALOGUE]
#  #Person1#: 바쁜 한 주 보냈어?
# #Person2#: 음, 아니, 뭐 많이 하진 않았는데 컴퓨터를 샀어.
# #Person1#: 오, 샀어? 정말 다행이다. 이제 내 컴퓨터 안 빌려도 되겠다. 지난번에 두 주 동안 썼었잖아.
# #Person2#: 맞아, 정말 미안해. 그때 역사 과제 쓰느라 썼거든. 다시 한 번 고마워.
# #Person1#: 어, 괜찮아. 그럼 네 컴퓨터는 어때?
# #Person2#: 오, 진짜 멋져. 매일 써.
# #Person1#: 정말? 수업에 쓰고 있는 거야? 지금 과제 하고 있는 거 맞지?
# #Person2#: 맞아, 그런데 수업으로 쓰는 건 아니야.
# #Person1#: 그럼 뭐 하는 데 쓰니?
# #Person2#: 사실 그냥 일주일 내내 DVD 보는 데 써.
#
# [SUMMARY]
#  #Person2#는 새 컴퓨터를 구입했고, #Person1#에게 컴퓨터를 빌려준 것에 대해 고마움을 표현합니다. #Person2#는 주로 DVD 보는 데 컴퓨터를 사용합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2913
# topic: 수업 지각
# [DIALOGUE]
#  #Person1#: 오늘 수업에 늦어서 죄송해요, Dr. Simpson.
# #Person2#: 이번엔 그냥 넘어가겠지만, 다른 학생들에게 방해가 됐다는 걸 알지?
# #Person1#: 네, 그걸 느꼈어요. 다시는 안 그러도록 할게요.
#
# [SUMMARY]
#  #Person1#이 Dr. Simpson에게 수업에 다시는 늦지 않겠다고 약속합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7535
# topic: 잘못 걸린 전화
# [DIALOGUE]
#  #Person1#: 여보세요. Brian 좀 바꿔주실 수 있나요?
# #Person2#: 죄송하지만, 잘못 거셨어요. 여기엔 Brian이라는 사람이 없어요.
# #Person1#: 여기 #PhoneNumber# 맞나요?
# #Person2#: 아니에요, 여기는 #PhoneNumber#이에요.
# #Person1#: 아, 정말 죄송해요.
# #Person2#: 괜찮습니다.
#
# [SUMMARY]
#  #Person1#이 Brian에게 전화를 걸었으나 잘못된 번호로 연결되었습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2655
# topic: 논문 찾기
# [DIALOGUE]
#  #Person1#: 왜 이렇게 우울해 보여? 뭐 찾고 있어?
# #Person2#: 내 논문. 어젯밤 어딘가에 두었는데 지금 찾을 수가 없어.
# #Person1#: 어제 타이핑 다 마쳤어?
# #Person2#: 응, 자정까지 그거 계속 타이핑했는데, 잃어버렸어.
# #Person1#: 걱정하지 마. 분명 네 방 어딘가에 있을 거야. 어디에 두었는지 보자. 서랍이랑 책상은 다 찾아봤어?
# #Person2#: 응, 근데 서랍 안에도 책상 위에도 아무것도 없어.
# #Person1#: 선반은 어때?
# #Person2#: 어디든 다 찾아봤어. 대체 어디에 둔 거지?
# #Person1#: 너무 실망하지 마. 적어도 아직 일주일 여유 있잖아.
# #Person2#: 한 달 내내 그거 하느라 고생했는데, 다시 쓰기엔 너무 늦었어. 내 모든 노력이 수포로 돌아가잖아. 어떻게 이럴 수가 있지?
# #Person1#: 기운 내! 내가 말하고 싶은 건, 일주일 동안 찾을 수 있을 거라는 거야. 새로 쓸 필요 없어. 어, 이게 뭐지? 이거 네 논문 아니야?
# #Person2#: 좀 보여줘. 맞아, 그거야. 어디서 찾았어?
# #Person1#: 너 이 저널들 사이에 두었더라고.
# #Person2#: 내 나쁜 기억력. 정말 고마워.
#
# [SUMMARY]
#  #Person2#는 자신의 논문을 어디에 두었는지 잊어버려서 우울해합니다. 논문은 서랍이나 책상 위에 없었습니다. #Person1#은 #Person2#를 위로하며 함께 논문을 찾는데, 결국 #Person2#가 저널들 사이에 논문을 두었음을 알아냅니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1275
# topic: 민속 행사 공연 준비
# [DIALOGUE]
#  #Person1#: 정부에서 이달 말에 민속 행사를 조직할 예정이야. 우리 커뮤니티에서도 공연을 해야 해.
# #Person2#: 어떤 공연이야? 사자춤 같은 거?
# #Person1#: 그런 거긴 한데, 사자춤은 좀 어렵고 위험할 것 같아.
# #Person2#: 그렇지, 사자랑 춤추는 건데. 기대가 크네? 그럼 전에 했던 '레인지 댄스' 어때?
# #Person1#: 좋은 생각이야. 우리 커뮤니티 사람들 다 참여하게 할까?
# #Person2#: 그럴 필요는 없을 것 같아. 그냥 은퇴하신 어르신들에 집중하자.
# #Person1#: 맞아, 이미 레인지 댄스 팀이 있으니까 연습만 좀 하면 되겠네.
# #Person2#: 의상은 어떻게 하지?
# #Person1#: 커뮤니티에서 돈을 모을 수 있어. 각 가정에서 10위안씩 내면 될 것 같아.
# #Person2#: 새로운 방법을 시도해보자. 지원해줄 기관을 찾아보자.
# #Person1#: 좋은 생각이야. 근처에 여행사가 있는데, 우리 후원이 되어줄 수 있을 것 같아. 민족 관광 홍보하는 좋은 기회가 될 거야.
#
# [SUMMARY]
#  #Person1#와 #Person2#는 민속 행사에서 '레인지 댄스'를 하기로 결정했다. 그들은 은퇴하신 어르신들에 초점을 맞추고 여행사를 후원자로 찾기로 했다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_4336
# topic: 직장 고민
# [DIALOGUE]
#  #Person1#: 연말 평가 어떻게 됐어?
# #Person2#: 그냥 그랬어. 오늘 아침에 Mitch랑 회의를 했는데, 결론은 더 주도적으로 해야 한다는 거야. 더 창의적으로 해야 한다고 생각한대.
# #Person1#: 실제로 그렇게 말했어?
# #Person2#: 아니, 꼭 그렇게 말한 건 아닌데, 생산성이 큰 문제인 것 같아. '지금처럼 열심히 해' 나 '수고했어' 같은 말도 했지만, 우리 부서에 직원 몇 명을 더 고용하려고 생각 중이라던데, 그건 내가 잘 못하고 있다는 의미인 것 같아.
# #Person1#: 네가 너무 깊게 생각하는 거 아닐까?
# #Person2#: 아니, 그럴 일 없지. 내가 더 잘하지 않으면 내 일이 위험할 것 같아.
# #Person1#: 음, 난 네가 좀 과민반응하는 거라고 생각하는데. Mitch는 다들 건설적인 비판을 해주고 싶어 하잖아. 그냥 그런 것 같아.
# #Person2#: 정말 그렇게 생각해?
# #Person1#: 응, 그래. 다른 사람들한테 물어봐도 같은 얘기를 할 거야.
# #Person2#: 네 말이 맞을 수도 있겠다. 고마워, Don. 기분 나아졌어.
# #Person1#: 네가 그렇게 생각하니 나도 기뻐.
#
# [SUMMARY]
#  #Person2#는 Mitch가 해준 연말 평가에 부정적이었다. Mitch가 #Person2#의 업무에 만족하지 않는 것처럼 느꼈기 때문이다. 하지만 #Person1#은 Mitch가 건설적인 비판을 좋아한다고 말하면서 #Person2#의 기분이 나아지게 했다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_113
# topic: 통화 연결 문제
# [DIALOGUE]
#  #Person1#: 여보세요, Mr. Wu인가요?
# #Person2#: 네, 맞습니다. 무슨 일이신가요?
# #Person1#: 몇 가지 정보를 여쭤보려고 전화 드렸어요.
# #Person2#: 통화 상태가 안 좋은데요. 다시 말씀해 주실 수 있나요?
# #Person1#: 아까 전에 정보를 여쭤보고 싶다고 말했어요.
# #Person2#: 죄송해요, 연결 상태가 너무 안 좋아요. 제가 다시 전화드릴게요. 아무것도 들리지 않네요.
#
# [SUMMARY]
#  #Person1#이 Mr. Wu에게 정보를 문의하려고 전화했으나 연결 상태가 좋지 않았습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_3781
# topic: 수도꼭지 누수
# [DIALOGUE]
#  #Person1#: 이게 뭐야! 수도꼭지가 또 심하게 새고 있어.새고 있어.
# #Person2#: 저러다 요금 엄청 나올 거야.
# #Person1#: 맞아. 최대한 빨리 고쳐야겠어.
# #Person2#: 지금 고치려는 거 아니야?
# #Person1#: 그랬으면 좋겠지만, 지금 나가야 해. 20분 후에 약속이 있어.
# #Person2#: 뭐 필요한 거 있으면 말해.
# #Person1#: 아, 그런데 나 좀 태워줄 수 있어? 내 차 아직 정비소에 있어.
# #Person2#: 요즘 운이 참 없구나.
#
# [SUMMARY]
#  #Person1#은 수도꼭지가 심하게 새고 있어 걱정하고 있습니다. 하지만 약속이 있어 지금 고치지 못하고, #Person2#에게 차가 정비소에 있으니 태워달라고 부탁합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6494
# topic: 날씨와 기분
# [DIALOGUE]
#  #Person1#: 난 이런 날씨 정말 싫어!
# #Person2#: 어릴 적에 나쁜 날씨란 없다고 말하던 사람이 있었어.
# #Person1#: 그 사람은 머리가 좀 이상했나 봐. 이건 정말 별로야.
# #Person2#: 그는 모든 날씨가 그저 좋은 날씨일 뿐이라고 했어.
# #Person1#: 그래, 그럼 이 날씨가 뭐가 그렇게 좋은 건데?
# #Person2#: 글쎄, 집에 있을 수 있는 좋은 핑계가 생겼잖아.
# #Person1#: 집에 있을 수 있다고? 너, 내가 모르는 무슨 정보를 아는 거야?
# #Person2#: 부엌에 핫초코 준비되어 있고, 새 CD들이 우리를 기다리고 있다는 걸 알지.
#
# [SUMMARY]
#  #Person1#은 날씨를 싫어하지만, #Person2#는 날씨에서 좋은 점을 찾으려고 합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_2884
# topic: 이혼과 교훈
# [DIALOGUE]
#  #Person1#: 결국 그 사람들 이혼했대.
# #Person2#: 어쩔 수 없었던 것 같아. 그들의 사랑은 지속될 수 없었겠지.
# #Person1#: 맞아, 모래 위에 쌓은 사랑은 쉽게 무너지니까.
# #Person2#: 우리에게도 많은 것을 생각하게 하네.
#
# [SUMMARY]
#  #Person1#과 #Person2#는 이혼한 커플에 대해 대화하며 교훈을 얻습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_10329
# topic: 미국 방문 계획
# [DIALOGUE]
#  #Person1#: 앉으시겠어요? 여러 가지 질문을 좀 드리려고 하는데 괜찮으실까요?
# #Person2#: 네, 괜찮습니다. 말씀하세요.
# #Person1#: 미국에 오신 목적은 무엇인가요?
# #Person2#: 대기 오염 관련 회의에 참석하려고 합니다.
# #Person1#: 그 회의는 언제, 어디서 열리나요?
# #Person2#: 2월 첫 3주 동안 캘리포니아의 스탠포드 대학에서 열려요.
# #Person1#: 경비는 누가 부담하시나요?
# #Person2#: 캘리포니아 대학에서 부담합니다. 공식 초청장이 여기 있습니다.
# #Person1#: 알겠습니다. 좋습니다. 언제 출발하실 예정이신가요?
# #Person2#: 여권이 준비되면 1월 중순에 출발하고 싶습니다.
# #Person1#: 그리 어렵지 않을 겁니다. 1월 10일쯤에 연락 주시면 그때 답변을 드릴 수 있을 겁니다.
# #Person2#: 감사합니다.
#
# [SUMMARY]
#  #Person1#은 #Person2#의 미국 방문 계획에 대해 상세히 묻습니다. #Person2#는 1월 중순에 출발할 예정이며, #Person1#에게 연락해 답변을 받을 계획입니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_11600
# topic: 보험 혜택 논의
# [DIALOGUE]
#  #Person1#: 오늘은 관심 있으신 보험에 대해 이야기해 볼게요.
# #Person2#: 감사합니다. 생명보험과 건강보험에 대해 알 수 있을까요?
# #Person1#: 물론이에요. 저희는 연중 2주 유급휴가와 주 5일 근무제를 제공합니다.
# #Person2#: 좋네요. 또 다른 혜택이 있나요?
# #Person1#: 네, 모든 보험은 귀하의 업무와 연계될 거고, 저희가 보험 증권을 발급해 드릴게요.
#
# [SUMMARY]
#  #Person1#은 #Person2#에게 관심 있는 보험과 관련 혜택을 설명합니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_1399
# topic: 실업 수당
# [DIALOGUE]
#  #Person1#: 이번 주에 실업 수당을 못 받았는데, 왜 그런지 알아보려고 전화했어요.
# #Person2#: 최근 기간의 연속 청구 양식을 보내셨나요?
# #Person1#: 깜빡하고 안 보낸 것 같아요!
# #Person2#: 급여를 받으시려면 그 양식을 2주마다 꼭 보내야 해요.
# #Person1#: 지금 보내면 될까요?
# #Person2#: 청구 양식을 보고 기한이 지난 지 14일이 넘지 않았는지 확인해 보세요. 넘지 않았다면, 저희가 받을 수 있어요.
# #Person1#: 다음번에는 늦지 않게 미리 보내도 될까요?
# #Person2#: 사실 미리 보낼 수는 없어요. 기한까지의 모든 정보를 반영해야 하니까요.
# #Person1#: 그럼 이제 곧 수표가 올까요?
# #Person2#: 수표가 조금 늦게 도착할 거예요.
#
# [SUMMARY]
#  #Person1#은 이번 주에 실업 수당을 받지 못한 이유를 알아보려 #Person2#에게 전화했습니다. #Person2#는 #Person1#이 연속 청구 양식을 보내는 것을 잊었기 때문이라고 설명했습니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_6703
# topic: 결혼 계획
# [DIALOGUE]
#  #Person1#: 와, 정말 신나네요. 그래서 어디에서 결혼하고 싶어요? 아, 알아요, 알아요. 음, 산 위에서요. 그 아름다운 폭포 알죠? 왜 그 폭포 옆에서 결혼하지 않아요?
# #Person2#: 음, 잘 모르겠어요.
# #Person1#: 아, 제발요. 정말 멋질 거예요. 너무 아름답고, 조용하고, 정말 로맨틱해요. 제발요.
# #Person2#: 글쎄요. 저는 32가지 야생화에 알레르기가 있는 거 아시잖아요...
# #Person1#: 괜찮을 거예요. 알레르기 약 먹으면 돼요.
# #Person2#:... 그리고 얼굴에 심한 두드러기가 날 수도 있어요.
# #Person1#: 괜찮을 거예요. 자, 어... 확실히 좋은 아이디어가 있을 거예요. 자, 생각해봐요.
# #Person2#: 우리... 우리... 우리... 부모님 뒷마당에서 결혼할 수도 있어요. [ 뭐라고? ] 네. 강아지들을 몇 시간 옮기기만 하면 돼요.
# #Person1#: 아니요! 생각도 하지 마세요. 그들의 뒷마당은 정말... 정말 (쓰레기 같은 걸 말하려는 거예요) 상태가 나빠요. 그리고 그 집은 고속도로 바로 옆이라 너무 시끄러워요. 정말 괜찮은 연회장이 몇 마일 안에 있어요. 거기서 할 수 있어요. 알레르기 걱정 안 해도 돼요.
# #Person2#: 아, 그거 비싸겠어요!
# #Person1#: 그렇게 비싸지 않아요... 조금 비싸지만 괜찮아요. 그리고 그리고, 보세요. 케이터링 서비스를 부를 수 있고, 그들이 새우랑 랍스터 꼬리를 제공해주고, 제 친구 결혼할 때 최고의 디저트가 있었어요. 그리고, 그리고, 아침식사로는 그 일본식당에 갈 수 있어요. 뭐라고 했더라?
# #Person2#: 아마 Samarai Sushi?
# #Person1#: 맞아요, Samuri Sushi! 거기 음식 정말 좋아요. 자, 자.
# #Person2#: 그거 너무 비싸 보이네요.
# #Person1#: 괜찮아요. 그만한 가치는 있어요. 자, Ron! 자!
# #Person2#: 대신 어머니의 참치 샌드위치는 어때요?
# #Person1#: Ronald
#
# [SUMMARY]
#  #Person1#은 산에서 결혼하자고 제안하지만 Ron은 알레르기를 걱정합니다. Ron은 부모님의 뒷마당을 제안하지만 #Person1#은 이를 반대하고 연회장을 추천합니다. Ron은 비용을 걱정하며 신혼여행을 위해 돈을 아끼려 합니다. #Person1#은 스노우보딩과 스키를 원하지만 Ron은 박물관을 방문하고 형의 집에 머물고 싶어합니다. #Person1#은 화가 나서 자리를 떠납니다.
#
#
#
# ==== SAMPLE ====
#
# fname: train_7608
# topic: 초과근무
# [DIALOGUE]
#  #Person1#: 저기, Mr. Li. 말씀드릴 게 있어요.
# #Person2#: 저 조금 바쁜데요, Ms. Liu. 잠깐만 기다려 주실래요?
# #Person1#: 지금 몇 분만 말씀 나눌 수 있으면 정말 감사하겠습니다. 요청하신 초과근무에 관한 건인데요.
# #Person2#: 그래요. 뭐가 문제죠?
# #Person1#: 제가 초과근무를 할 수가 없어요. 남편이 요즘 아파서 제가 돌봐야 하거든요.
# #Person2#: 안타깝네요. 남편 잘 돌봐주시고, 다른 사람 찾아볼게요.
#
# [SUMMARY]
#  Ms. Liu는 Mr. Li에게 초과근무를 할 수 없는 이유를 설명합니다. Mr. Li는 그녀를 대신할 다른 사람을 찾겠다고 약속합니다.

# %% [markdown]
# ## 7. KoBART 토크나이저 기준 토큰 길이 분포
#
# - 이 셀에서는 **KoBART 토크나이저**로 대화문을 토크나이즈했을 때 토큰 길이 분포를 봅니다.
# - encoder_max_len=1024 설정이 얼마나 여유 있는지, 잘리는 샘플 비율이 어느 정도인지 확인하는 목적입니다.

# %%
# KoBART 토크나이저를 불러와서, 대화문의 토큰 길이 분포를 확인하는 셀입니다.
# - encoder_max_len=1024 설정으로 충분한지 확인하기 위함입니다.
from transformers import PreTrainedTokenizerFast

kobart_tok = PreTrainedTokenizerFast.from_pretrained("gogamza/kobart-base-v1")

def token_len(text: str) -> int:
    return len(kobart_tok.encode(str(text), add_special_tokens=True))

train_df["dialogue_len_tok"] = train_df["dialogue"].apply(token_len)
dev_df["dialogue_len_tok"] = dev_df["dialogue"].apply(token_len)

print("[TRAIN] dialogue_len_tok describe:\n", train_df["dialogue_len_tok"].describe())
print("[DEV] dialogue_len_tok describe:\n", dev_df["dialogue_len_tok"].describe())
print("\n[TRAIN] encoder_max_len=1024 초과 비율:", (train_df["dialogue_len_tok"] > 1024).mean())
print("[DEV] encoder_max_len=1024 초과 비율:", (dev_df["dialogue_len_tok"] > 1024).mean())
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# [TRAIN] dialogue_len_tok describe:
#  count    12457.000000
# mean       199.561532
# std         93.123736
# min         42.000000
# 25%        141.000000
# 50%        183.000000
# 75%        245.000000
# max       1079.000000
# Name: dialogue_len_tok, dtype: float64
# [DEV] dialogue_len_tok describe:
#  count    499.000000
# mean     196.547094
# std       87.909245
# min       54.000000
# 25%      139.000000
# 50%      179.000000
# 75%      242.500000
# max      670.000000
# Name: dialogue_len_tok, dtype: float64
#
# [TRAIN] encoder_max_len=1024 초과 비율: 0.00024082844986754435
# [DEV] encoder_max_len=1024 초과 비율: 0.0

# %% [markdown]
# ## 8. 요약 길이 vs 대화 길이 상관 관계
#
# - 이 셀에서는 **대화 길이(문자 기준)**와 **요약 길이(문자 기준)**의 상관 관계를 계산합니다.
# - "대화가 길어질수록 요약도 길어지는지" 대략적인 경향을 보는 것이 목적입니다.

# %%
# 대화 길이(문자)와 요약 길이(문자)의 상관 관계를 계산하는 셀입니다.
# - scatter plot까지는 아니지만, 상관 계수로 대략적인 경향을 봅니다.
corr = train_df[["dialogue_len_char", "summary_len_char"]].corr()
print("[TRAIN] dialogue_len_char vs summary_len_char 상관 계수:\n", corr)
# Out:
# [TRAIN] dialogue_len_char vs summary_len_char 상관 계수:
#                     dialogue_len_char  summary_len_char
# dialogue_len_char           1.000000          0.716915
# summary_len_char            0.716915          1.000000

# %% [markdown]
# ## 9. 요약 스타일 키워드 빈도
#
# - 이 셀에서는 요약문에서 자주 등장하는 단어를 세어 봅니다.
# - "환자", "고객", "상담", "예약" 등 어떤 표현이 많이 나오는지 보고,
#   요약 스타일(예: 의료/상담/일상 대화 비율)을 감각적으로 파악하는 것이 목적입니다.

# %%
# 요약문에서 자주 등장하는 단어의 빈도를 간단히 계산하는 셀입니다.
# - 형태소 분석까지는 하지 않고, 한글/영문/숫자 토큰 기준으로 rough하게 봅니다.
from collections import Counter
import re

def tokenize_korean(text: str):
    return re.findall(r"[가-힣A-Za-z0-9]+", str(text))

words = []
sample_summaries = train_df["summary"].dropna().sample(min(1000, len(train_df)), random_state=42)
for s in sample_summaries:
    words.extend(tokenize_korean(s))

counter = Counter(words)
print("[요약문 상위 50개 토큰 빈도]")
for w, c in counter.most_common(50):
    print(w, c)
# Out:
# [요약문 상위 50개 토큰 빈도]
# Person1 1099
# Person2 993
# 는 625
# 은 539
# 에게 353
# 대해 212
# 이 154
# 의 138
# 과 124
# 가 117
# 설명합니다 95
# 합니다 93
# 위해 90
# 수 82
# 것을 78
# 있습니다 61
# 말합니다 56
# 함께 55
# 더 54
# 있다고 53
# 있으며 50
# 요청합니다 46
# 한다 45
# Mr 45
# 대한 42
# 이야기합니다 42
# 있는 40
# 생각합니다 40
# 그 37
# 그들은 36
# 하고 35
# 자신의 32
# 안내합니다 32
# 제안합니다 31
# 있다 31
# 싶어 30
# 후 30
# 두 28
# 것이라고 28
# 말한다 27
# 찾고 27
# 결국 27
# 이를 26
# 와 26
# 큰 23
# 새 23
# 것이 23
# 그리고 23
# 하며 22
# 설명한다 22

# %% [markdown]
# ## 10. train vs dev 길이 분포 비교
#
# - 이 셀에서는 train/dev 간에 **대화 길이/요약 길이 평균**이 얼마나 다른지 비교합니다.
# - train과 dev 분포가 크게 다르면, dev 성능이 실제 test 분포와도 다를 수 있으므로,
#   분포 차이를 확인하는 것이 목적입니다.

# %%
# train과 dev의 길이 분포(평균 기준)를 비교하는 셀입니다.
print("[TRAIN] dialogue_len_char mean:", train_df["dialogue_len_char"].mean())
print("[DEV]   dialogue_len_char mean:", dev_df["dialogue_len_char"].mean())
print("[TRAIN] summary_len_char mean:", train_df["summary_len_char"].mean())
print("[DEV]   summary_len_char mean:", dev_df["summary_len_char"].mean())
# Out:
# [TRAIN] dialogue_len_char mean: 406.0834871959541
# [DEV]   dialogue_len_char mean: 400.0541082164329
# [TRAIN] summary_len_char mean: 85.78943565866581
# [DEV]   summary_len_char mean: 81.2064128256513

# %% [markdown]
# ## 11. prediction sanity check
#
# - 이 셀에서는 현재까지 생성한 **제출용 CSV**를 간단히 검증합니다.
# - 예: `fname` 중복 여부, summary가 비어 있는지, 길이 분포가 너무 극단적이지 않은지 확인합니다.
# - 아래 파일명은 예시이며, 실제로 확인하고 싶은 최신 CSV 경로로 수정해서 사용하면 됩니다.

# %%
# 생성된 prediction CSV가 기본 형식을 잘 따르는지 확인하는 셀입니다.
# - fname 중복/누락, summary 공백 비율, 요약 길이 분포 등을 간단히 체크합니다.

PRED_PATH = "prediction/2511292249_kobart-base-style_prompt_bs8.csv"  # 필요에 따라 최신 파일로 변경

try:
    pred_df = pd.read_csv(PRED_PATH)
except FileNotFoundError:
    print(f"파일을 찾을 수 없습니다: {PRED_PATH}")
else:
    print(pred_df.head())
    print("rows:", len(pred_df))
    print("fname unique:", pred_df["fname"].nunique())
    empty_ratio = (pred_df["summary"].astype(str).str.strip() == "").mean()
    print("empty summary 비율:", empty_ratio)
    print("summary 길이 통계:\n", pred_df["summary"].astype(str).str.len().describe())
# Out:
# 파일을 찾을 수 없습니다: prediction/2511292249_kobart-base-style_prompt_bs8.csv
